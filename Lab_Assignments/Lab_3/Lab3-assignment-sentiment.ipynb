# %% [markdown]
# # Lab3 - Assignment Sentiment

# %% [markdown]
# Copyright: Vrije Universiteit Amsterdam, Faculty of Humanities, CLTL

# %% [markdown]
# This notebook describes the LAB-3 assignment of the Text Mining course. It is about sentiment analysis.
#
# The aims of the assignment are:
# * Learn how to run a rule-based sentiment analysis module (VADER)
# * Learn how to run a machine learning sentiment analysis module (Scikit-Learn/ Naive Bayes)
# * Learn how to run scikit-learn metrics for the quantitative evaluation
# * Learn how to perform and interpret a quantitative evaluation of the outcomes of the tools (in terms of Precision, Recall, and F<sub>1</sub>)
# * Learn how to evaluate the results qualitatively (by examining the data)
# * Get insight into differences between the two applied methods
# * Get insight into the effects of using linguistic preprocessing
# * Be able to describe differences between the two methods in terms of their results
# * Get insight into issues when applying these methods across different  domains
#
# In this assignment, you are going to create your own gold standard set from 50 tweets. You will the VADER and scikit-learn classifiers to these tweets and evaluate the results by using evaluation metrics and inspecting the data.
#
# We recommend you go through the notebooks in the following order:
# * **Read the assignment (see below)**
# * **Lab3.2-Sentiment-analysis-with-VADER.ipynb**
# * **Lab3.3-Sentiment-analysis.with-scikit-learn.ipynb**
# * **Answer the questions of the assignment (see below) using the provided notebooks and submit**
#
# In this assignment you are asked to perform both quantitative evaluations and error analyses:
# * a quantitative evaluation concerns the scores (Precision, Recall, and F<sub>1</sub>) provided by scikit's classification_report. It includes the scores per category, as well as micro and macro averages. Discuss whether the scores are balanced or not between the different categories (positive, negative, neutral) and between precision and recall. Discuss the shortcomings (if any) of the classifier based on these scores
# * an error analysis regarding the misclassifications of the classifier. It involves going through the texts and trying to understand what has gone wrong. It servers to get insight in what could be done to improve the performance of the classifier. Do you observe patterns in misclassifications?  Discuss why these errors are made and propose ways to solve them.

# %% [markdown]
# ## Credits
# The notebooks in this block have been originally created by [Marten Postma](https://martenpostma.github.io) and [Isa Maks](https://research.vu.nl/en/persons/e-maks). Adaptations were made by [Filip Ilievski](http://ilievski.nl).

# %% [markdown]
# ## Part I: VADER assignments
#
#
# ### Preparation (nothing to submit):
# To be able to answer the VADER questions you need to know how the tool works.
# * Read more about the VADER tool in [this blog](http://t-redactyl.io/blog/2017/04/using-vader-to-handle-sentiment-analysis-with-social-media-text.html).
# * VADER provides 4 scores (positive, negative, neutral, compound). Be sure to understand what they mean and how they are calculated.
# * VADER uses rules to handle linguistic phenomena such as negation and intensification. Be sure to understand which rules are used, how they work, and why they are important.
# * VADER makes use of a sentiment lexicon. Have a look at the lexicon. Be sure to understand which information can be found there (lemma?, wordform?, part-of-speech?, polarity value?, word meaning?) What do all scores mean? https://github.com/cjhutto/vaderSentiment/blob/master/vaderSentiment/vader_lexicon.txt)
#
#
# ### [3.5 points] Question1:
#
# Regard the following sentences and their output as given by VADER. Regard sentences 1 to 7, and explain the outcome **for each sentence**. Take into account both the rules applied by VADER and the lexicon that is used. You will find that some of the results are reasonable, but others are not. Explain what is going wrong or not when correct and incorrect results are produced.
#
# ```
# INPUT SENTENCE 1 I love apples
# VADER OUTPUT {'neg': 0.0, 'neu': 0.192, 'pos': 0.808, 'compound': 0.6369}
#
# INPUT SENTENCE 2 I don't love apples
# VADER OUTPUT {'neg': 0.627, 'neu': 0.373, 'pos': 0.0, 'compound': -0.5216}
#
# INPUT SENTENCE 3 I love apples :-)
# VADER OUTPUT {'neg': 0.0, 'neu': 0.133, 'pos': 0.867, 'compound': 0.7579}
#
# INPUT SENTENCE 4 These houses are ruins
# VADER OUTPUT {'neg': 0.492, 'neu': 0.508, 'pos': 0.0, 'compound': -0.4404}
#
# INPUT SENTENCE 5 These houses are certainly not considered ruins
# VADER OUTPUT {'neg': 0.0, 'neu': 0.51, 'pos': 0.49, 'compound': 0.5867}
#
# INPUT SENTENCE 6 He lies in the chair in the garden
# VADER OUTPUT {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.4215}
#
# INPUT SENTENCE 7 This house is like any house
# VADER OUTPUT {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.3612}
# ```
# ## Sentence Analysis
#
# Overall notes about VADER: The VADER library is a very powerful and popular lexicon-based sentiment analysis tool
# used in many areas of natural language processing. VADER first breaks down the text into individual words(tokens),
# then each word(token) is assigned a sentiment score based on the "vader_lexicon.txt" file, identifying each word
# as either negative, neutral or positive. After all of this is done, VADER computes a 'compound' value which is the
# overall sentiment of the text. What makes VADER so powerful and popular is its ability to identify the intensity of
# sentiment; for example, capitalization, punctuation, and reinforcing words (modifiers) have a large impact on the
# sentiment of the overall text.
#
# Based on the notes about VADER, let's analyze the above sentences:
#
# * Sentence 1: For this sentence the compound score seems reasonable, looking at each word in the sentence ['I',
# 'love', 'apples'] the word 'I' is mostly neutral, the word 'apples' does not exist within the lexicon file so is
# most likely assumed neutral as well, however; the word 'love' is in the lexicon file (and has an individual mean
# score of 3.2), accompanied by the fact that it is an intensifier for the neutral word 'I' the compound score makes
# sense here.
#
# * Sentence 2: For this sentence the compound score seems more interesting, looking at each word again the only
# difference in this sentence is the addition of the word "don't," which negates the first sentence. Although the
# sentiment value for somebody writing 'I love apples' and 'I don't love apples' is the same for humans, VADER seems
# more unsure when the sentence is negated and therefore gives a greater 'neu' value. This shows us that common human
# text which includes jokes, irony, sarcasm, and negations will be difficult for VADER to understand due to its
# rule-based nature.
#
# * Sentence 3: For this sentence the compound score makes a lot of sense, it is the same as the first sentence
# except for the addition of ':-)' at the end, in the 'vader_lexicon.txt' file the smiley face has a mean score of 1.3, and while it is not a hugely large score it does have some form of intensity, therefore, when coupled with
# 'love' brings the compound score from about 0.64 to 0.76 which is a significant difference.
#
# * Sentence 4: For this sentence the compound score does not make a lot of sense, for humans such a sentence would
# have a significantly larger negative score than it does for VADER (depending on the context, of course). This
# sentence contains the word 'ruins' at the end (with a mean score of -1.9), and although there is heavy intensity
# projected onto the word 'houses,' VADER seems to not take this as much into account as humans would. This is another
# example of where complex language structures cannot be fully captured via lexicon(rule)-based systems.
#
# * Sentence 5: For this sentence the compound does make sense, considering the explanation regarding sentence 4.
# Following the previous explanation, although a human would interpret this sentence more neutrally, the negation
# of the word 'ruins' and the inclusion of the word 'certainly' before the negation (with an individual mean score of
# 1.4). While the mean score for 'certainly' is not high because VADER struggles with the negation of the negative
# word 'ruins' and 'certainly' is a positive word (which can also be considered a slight intensifier), the compound
# score reflects these elements in the sentence.
#
# * Sentence 6: For this sentence the compound score is very strange, for any human this sentence is purely
# informational, there is no emotion or response attached to this sentence without further context. Because
# the word 'lies' is present within the sentence (with an individual mean score of -1.8) and intensifies both 'chair'
# and 'garden,' the compound score reflects the intensity projected on the overall sentence.
#
# * Sentence 7: Lastly, for this sentence the compound score is also a bit skewed, but less than sentence 6. Once
# again, this sentence is purely informational and meant to convey that a house is similar to other houses, although
# we are unsure of which qualities are compared, this is generally a neutral sentence. Having said that, we do also
# understand that because of the word 'like' (which has an individual mean score of 1.5), and the intensity
# amplification on the word 'house,' that the compound score is slightly raised.

# %% [markdown]
# ### [Points: 2.5] Exercise 2: Collecting 50 tweets for evaluation
# Collect 50 tweets. Try to find tweets that are interesting for sentiment analysis, e.g., very positive, neutral, and negative tweets. These could be your own tweets (typed in) or collected from the Twitter stream. If you have trouble accessing Twitter, try to find an existing dataset (on websites like kaggle or huggingface).
#
# We will store the tweets in the file **my_tweets.json** (use a text editor to edit).
# For each tweet, you should insert:
# * sentiment analysis label: negative | neutral | positive (this you determine yourself, this is not done by a computer)
# * the text of the tweet
# * the Tweet-URL
#
# from:
# ```
#     "1": {
#         "sentiment_label": "",
#         "text_of_tweet": "",
#         "tweet_url": "",
# ```
# to:
# ```
# "1": {
#         "sentiment_label": "positive",
#         "text_of_tweet": "All across America people chose to get involved, get engaged and stand up. Each of us can make a difference, and all of us ought to try. So go keep changing the world in 2018.",
#         "tweet_url" : "https://twitter.com/BarackObama/status/946775615893655552",
#     },
# ```

# %% [markdown]
# You can load your tweets with human annotation in the following way.

# %%
import json

# %%
my_tweets = json.load(open('my_tweets.json'))

# %%
for id_, tweet_info in my_tweets.items():
    print(id_, tweet_info)
    break
# Out:
# 1 {'sentiment_label': 'negative', 'text_of_tweet': 'michelle trachtenberg has sadly passed away at the age of 39. rest in peace', 'tweet_url': 'https://x.com/PopCulture2000s/status/1894804536650334363'}

# %% [markdown]
# ### [5 points] Question 3:
#
# Run VADER on your own tweets (see function **run_vader** from notebook **Lab2-Sentiment-analysis-using-VADER.ipynb**). You can use the code snippet below this explanation as a starting point.
# * [2.5 points] a. Perform a quantitative evaluation. Explain the different scores, and explain which scores are most relevant and why.
# * [2.5 points] b. Perform an error analysis: select 10 positive, 10 negative and 10 neutral tweets that are not correctly classified and try to understand why. Refer to the VADER-rules and the VADER-lexicon. Of course, if there are less than 10 errors for a category, you only have to check those. For example, if there are only 5 errors for positive tweets, you just describe those.

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from sklearn.metrics import classification_report

sia = SentimentIntensityAnalyzer()

def run_vader(tweet):
    """
    Runs VADER sentiment analysis on a given tweet.
    
    :param str tweet: The text of the tweet
    :return: The VADER sentiment output as a dictionary
    """
    return sia.polarity_scores(tweet)

def vader_output_to_label(vader_output):
    """
    map vader output e.g.,
    {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4215}
    to one of the following values:
    a) positive float -> 'positive'
    b) 0.0 -> 'neutral'
    c) negative float -> 'negative'
    
    :param dict vader_output: output dict from vader
    
    :rtype: str
    :return: 'negative' | 'neutral' | 'positive'
    """
    compound = vader_output['compound']
    
    if compound < 0:
        return 'negative'
    elif compound == 0.0:
        return 'neutral'
    elif compound > 0.0:
        return 'positive'
    
assert vader_output_to_label( {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.0}) == 'neutral'
assert vader_output_to_label( {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.01}) == 'positive'
assert vader_output_to_label( {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': -0.01}) == 'negative'

# %%
tweets = []
all_vader_output = []
gold = []

# settings (to change for different experiments)
to_lemmatize = True 
pos = set()

for id_, tweet_info in my_tweets.items():
    the_tweet = tweet_info['text_of_tweet']
    vader_output = run_vader(the_tweet)# run vader
    vader_label = vader_output_to_label(vader_output)# convert vader output to category
    
    tweets.append(the_tweet)
    all_vader_output.append(vader_label)
    gold.append(tweet_info['sentiment_label'])
    
# use scikit-learn's classification report
print(classification_report(gold, all_vader_output))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.78      0.72        18
#      neutral       0.86      0.35      0.50        17
#     positive       0.59      0.87      0.70        15
#
#     accuracy                           0.66        50
#    macro avg       0.70      0.67      0.64        50
# weighted avg       0.71      0.66      0.64        50

# %% [markdown]
# # Explanation of relevant scores and why they are relevant
#
# *

# %%
print(tweets)
# Out:
# ['michelle trachtenberg has sadly passed away at the age of 39. rest in peace', 'Your a War Criminal - Thousands are dead because of you', 'I guess this is a controversial opinion but men can be raped and abused by women', "If Elon didn't buy Twitter, it's entirely possible that Kamala would be president right now. Terrifying thought", 'Leaking ICE raid details is not just betrayal, it is a national security risk', 'Nazis and racists get to spew hate all day on this app but NBA Centel does a little trolling and gets banned. interesting', 'Dad looking annoyed and mum crying with disappointment that it’s a girl', 'As a father this has to be your worst nightmare', "Complete batshit lunacy on the president's Truth Social account", 'Nigga that got killed by that white lady digital footprint is HORRIBLE', 'Zookeepers in China gave this poor lion a bad haircut. Faced Public Backlash.', 'I would be so pissed if I lived in lumiose city', 'every animal i’ve interacted with today has been very mean to me and it makes me upset', 'I am genuinely losing my mind what in the ever-loving hell is the minecraft movie', 'Federal worker starts crying about losing her job', 'So fascinated by these people who think seed oils and vaccines are dangerous and unnatural but still get filler', 'On Facebook the bastard who owns it needs to stop all the animal cruelty videos,in fact any animal videos it is extremely cruel violent abuse of innocent animals the fuckers abusing monkeys need tracking down and dealing with and all who think it ok', 'The most dangerous animal on the planet, a violent creature filled with hateful thoughts and a lust for blood', 'I’m convinced that pandas are just drunk people in costumes', 'Animals reacting to themselves in the mirror in jungle', 'Penguin paints a picture and is extremely pleased with herself', 'The professor banned laptops so the students had to find a way', 'Unfortunately, as President Bukele eloquently articulates, there is no other option', 'On this day one year ago, TikToker mr.weatherall posted the following video', 'rest in peace michelle trachtenberg. thank you for the childhood memories', 'I regret to inform you that this site still has the juice', 'This is a very important dog. This dog has a good heart.', 'Fire department and animal control personnel rescue a very scared and cold dog', 'Elephant throwing dirt on a Nile Crocodile for some reason', 'Elon Musk has been receiving many death threats lately because he is exposing deep-rooted corruption & working to save the country from bankruptcy—all without charging a single penny', 'An elderly Lion in his final hours', 'Elon Musk has surpassed 219 million followers. He is the most followed account on 𝕏', '9 months old baby horse sees sea for the first time', 'this is so unfunny yet the funniest thing ever to me', 'All citizens of Sweden are Swedish', 'The Black Panther closed his eyes & just seemed so content. My heart melted♥️', 'Rocket, the majestic male tiger of the Pilibhit Tiger Reserve, in India truly lives up to his bold and regal appearance', 'This is so beautiful it’s almost scary', 'A beautiful bond between K-9 and his handler', 'I’ll say, it’s nice to have someone actually say this', 'Thirty-two years together and you still take my breath away. Happy Valentine’s Day', '10 terrifying beauties of wildlife', 'Gorgeous grey wolf becomes a good boy when visited by the people that helped raise their pack', 'THIS DOG AND DEER BEING FRIENDS IS LITERALLY THE CUTEST THING EVER 😍😭', 'I have no idea what is happening here but it is the best thing I’ve seen today', 'This is my favorite video on the internet', 'The swans love dance in winter', 'The best shot in television history', 'I’m proud to be Swedish because of my ancestors’ hard work in building my beloved Sweden', 'Beautiful bonding between Mother-Son']

# %%
print(all_vader_output)
# Out:
# ['positive', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'positive', 'neutral', 'positive', 'negative', 'negative', 'neutral', 'positive', 'negative', 'positive', 'negative', 'negative', 'negative', 'neutral', 'neutral', 'neutral', 'positive', 'neutral', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive']

# %%
print(gold)
# Out:
# ['negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive']

# %%
incorrect_positive = []
incorrect_negative = []
incorrect_neutral = []

for tweet, pred, actual in zip(tweets, all_vader_output, gold):
    if pred != actual:
        if actual == "positive":
            incorrect_positive.append(tweet)
        elif actual == "negative":
            incorrect_negative.append(tweet)
        elif actual == "neutral":
            incorrect_neutral.append(tweet)

# Show misclassified tweets (up to 10 per category)
print("Incorrectly classified positive tweets:", incorrect_positive[:10])
print("Incorrectly classified negative tweets:", incorrect_negative[:10])
print("Incorrectly classified neutral tweets:", incorrect_neutral[:10])
# Out:
# Incorrectly classified positive tweets: ['The Black Panther closed his eyes & just seemed so content. My heart melted♥️', '10 terrifying beauties of wildlife']
# Incorrectly classified negative tweets: ['michelle trachtenberg has sadly passed away at the age of 39. rest in peace', 'Leaking ICE raid details is not just betrayal, it is a national security risk', "Complete batshit lunacy on the president's Truth Social account", 'So fascinated by these people who think seed oils and vaccines are dangerous and unnatural but still get filler']
# Incorrectly classified neutral tweets: ['I’m convinced that pandas are just drunk people in costumes', 'Penguin paints a picture and is extremely pleased with herself', 'The professor banned laptops so the students had to find a way', 'Unfortunately, as President Bukele eloquently articulates, there is no other option', 'rest in peace michelle trachtenberg. thank you for the childhood memories', 'I regret to inform you that this site still has the juice', 'This is a very important dog. This dog has a good heart.', 'Fire department and animal control personnel rescue a very scared and cold dog', 'Elephant throwing dirt on a Nile Crocodile for some reason', 'Elon Musk has been receiving many death threats lately because he is exposing deep-rooted corruption & working to save the country from bankruptcy—all without charging a single penny']

# %% [markdown]
# # Error analysis and explanation
#
# *

# %% [markdown]
# ### [4 points] Question 4:
# Run VADER on the set of airline tweets with the following settings:
#
# * Run VADER (as it is) on the set of airline tweets
# * Run VADER on the set of airline tweets after having lemmatized the text
# * Run VADER on the set of airline tweets with only adjectives
# * Run VADER on the set of airline tweets with only adjectives and after having lemmatized the text
# * Run VADER on the set of airline tweets with only nouns
# * Run VADER on the set of airline tweets with only nouns and after having lemmatized the text
# * Run VADER on the set of airline tweets with only verbs
# * Run VADER on the set of airline tweets with only verbs and after having lemmatized the text
#
# * [1 point] a. Generate for all separate experiments the classification report, i.e., Precision, Recall, and F<sub>1</sub> scores per category as well as micro and macro averages. **Use a different code cell (or multiple code cells) for each experiment.**
# * [3 points] b. Compare the scores and explain what they tell you.
# * - Does lemmatisation help? Explain why or why not.
# * - Are all parts of speech equally important for sentiment analysis? Explain why or why not.

# %%
# Your code here
from sklearn.datasets import load_files
from collections import Counter
import spacy
import pathlib

vader_model = SentimentIntensityAnalyzer()
nlp = spacy.load('en_core_web_sm')
cwd = pathlib.Path.cwd()
airline_tweets_folder = cwd.joinpath('airlinetweets')
print('path:', airline_tweets_folder)

def run_vader(textual_unit, 
              lemmatize=False, 
              parts_of_speech_to_consider=None,
              verbose=0):
    """
    Run VADER on a sentence from spacy
    
    :param str textual unit: a textual unit, e.g., sentence, sentences (one string)
    (by looping over doc.sents)
    :param bool lemmatize: If True, provide lemmas to VADER instead of words
    :param set parts_of_speech_to_consider:
    -None or empty set: all parts of speech are provided
    -non-empty set: only these parts of speech are considered.
    :param int verbose: if set to 1, information is printed
    about input and output
    
    :rtype: dict
    :return: vader output dict
    """
    doc = nlp(textual_unit)
        
    input_to_vader = []

    for sent in doc.sents:
        for token in sent:

            to_add = token.text

            if lemmatize:
                to_add = token.lemma_

                if to_add == '-PRON-': 
                    to_add = token.text

            if parts_of_speech_to_consider:
                if token.pos_ in parts_of_speech_to_consider:
                    input_to_vader.append(to_add) 
            else:
                input_to_vader.append(to_add)

    scores = vader_model.polarity_scores(' '.join(input_to_vader))
    
    if verbose >= 1:
        print()
        print('INPUT SENTENCE', sent)
        print('INPUT TO VADER', input_to_vader)
        print('VADER OUTPUT', scores)

    return scores
# Out:
# path: /Users/robertostoica/Desktop/University_files_(year_3)_extra/period_4/Text Mining for AI/Assignments/Lab_Assignments/Lab_3/airlinetweets

# %%
from sklearn import metrics
path = str(airline_tweets_folder)
airline_tweets_train = load_files(path)
print(airline_tweets_train.target_names)

freqs = Counter(airline_tweets_train.target)
print(freqs)
print()
for category, frequency in freqs.items():
    print(category, frequency)
    print(airline_tweets_train.target_names[category], frequency)
# Out:
# ['negative', 'neutral', 'positive']
# Counter({0: 1750, 1: 1515, 2: 1490})
#
# 1 1515
# neutral 1515
# 2 1490
# positive 1490
# 0 1750
# negative 1750

# %%
# Running VADER as is on the set of airline tweets
for sentence in airline_tweets_train.data:
    baseline_text = sentence.decode("utf-8")
    run_vader(baseline_text, verbose=1)
# Out:
# INPUT SENTENCE Just wondering.
# INPUT TO VADER ['@AmericanAir', 'Why', 'is', 'your', 'cover', 'photo', 'of', 'TWA', '?', 'Just', 'wondering', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united next day
# INPUT TO VADER ['@united', 'next', 'day']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@JetBlue Thank you that it is not just a livery; it is a culture that 16
# INPUT TO VADER ['"', '@JetBlue', 'Thank', 'you', 'that', 'it', 'is', 'not', 'just', 'a', 'livery', ';', 'it', 'is', 'a', 'culture', 'that', '16']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.3612}
#
# INPUT SENTENCE @SouthwestAir I cannot DM you as you do not follow me.
# INPUT TO VADER ['@SouthwestAir', 'I', 'can', 'not', 'DM', 'you', 'as', 'you', 'do', 'not', 'follow', 'me', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@VirginAmerica Funny story
# INPUT TO VADER ['"', '@VirginAmerica', 'Funny', 'story']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.408, 'pos': 0.592, 'compound': 0.4404}
#
# INPUT SENTENCE @united flight 403 is delayed 40 min bc a missing screw and were in danger of missing flight 6491
# INPUT TO VADER ['@united', 'flight', '403', 'is', 'delayed', '40', 'min', 'bc', 'a', 'missing', 'screw', 'and', 'were', 'in', 'danger', 'of', 'missing', 'flight', '6491']
# VADER OUTPUT {'neg': 0.461, 'neu': 0.539, 'pos': 0.0, 'compound': -0.8442}
#
# INPUT SENTENCE @AmericanAir does it show that we are on the same plane?
# INPUT TO VADER ['@AmericanAir', 'does', 'it', 'show', 'that', 'we', 'are', 'on', 'the', 'same', 'plane', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Just sayin'.
# INPUT TO VADER ['@united', '@perfectomobile', 'You', 'really', 'should', "n't", 'use', 'the', 'word', "'", 'crashing', '.', "'", 'Just', 'sayin', "'", '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united what's a good number to call to speak with someone about how you can fix what you did to 50 people and their luggage on Saturday?
# INPUT TO VADER ['@united', 'what', "'s", 'a', 'good', 'number', 'to', 'call', 'to', 'speak', 'with', 'someone', 'about', 'how', 'you', 'can', 'fix', 'what', 'you', 'did', 'to', '50', 'people', 'and', 'their', 'luggage', 'on', 'Saturday', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.4939}
#
# INPUT SENTENCE Could Reservations help me?
# INPUT TO VADER ['@USAirways', 'I', 'm', 'researching', 'a', 'flight', '&', 'amp', ';', 'noticed', 'a', 'small', 'issue', 'w', '/', 'class', 'of', 'service', 'between', 'your', 'site', '&', 'amp', ';', 'other', 'sites', '.', 'Could', 'Reservations', 'help', 'me', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'compound': 0.4019}
#
# INPUT SENTENCE "@united never fails
# INPUT TO VADER ['"', '@united', 'never', 'fails']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.462, 'pos': 0.538, 'compound': 0.3252}
#
# INPUT SENTENCE "@united hi guys
# INPUT TO VADER ['"', '@united', 'hi', 'guys']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united broken light
# INPUT TO VADER ['"', '@united', 'broken', 'light']
# VADER OUTPUT {'neg': 0.608, 'neu': 0.392, 'pos': 0.0, 'compound': -0.4767}
#
# INPUT SENTENCE (2/2)
# INPUT TO VADER ['@united', 'to', 'speak', 'to', 'a', 'real', 'person', 'to', 'get', 'this', 'resolved', 'politely', 'and', 'efficiently', '.', '(', '2/2', ')']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.724, 'pos': 0.276, 'compound': 0.5537}
#
# INPUT SENTENCE @united love the new 1st class breakfast!
# INPUT TO VADER ['@united', 'love', 'the', 'new', '1st', 'class', 'breakfast', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.572, 'pos': 0.428, 'compound': 0.6696}
#
# INPUT SENTENCE "@USAirways just heard #Monterey airport was closed due to thick fog
# INPUT TO VADER ['"', '@USAirways', 'just', 'heard', '#', 'Monterey', 'airport', 'was', 'closed', 'due', 'to', 'thick', 'fog']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I have to book today.
# INPUT TO VADER ['@united', 'I', 'did', 'DM', 'the', 'details', 'but', 'still', 'no', 'response', '.', 'I', 'have', 'to', 'book', 'today', '.']
# VADER OUTPUT {'neg': 0.189, 'neu': 0.811, 'pos': 0.0, 'compound': -0.4215}
#
# INPUT SENTENCE I'll figure out car rental changes and such.
# INPUT TO VADER ['@united', 'yes', '1427', 'Cancelled', 'Flightled', '.', 'Moved', 'to', '333', '.', 'I', "'ll", 'figure', 'out', 'car', 'rental', 'changes', 'and', 'such', '.']
# VADER OUTPUT {'neg': 0.107, 'neu': 0.749, 'pos': 0.144, 'compound': 0.1779}
#
# INPUT SENTENCE And yes
# INPUT TO VADER ['"', '@USAirways', 'awesome', '!', 'And', 'yes']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.22, 'pos': 0.78, 'compound': 0.7959}
#
# INPUT SENTENCE #GetMartyHome
# INPUT TO VADER ['@united', 'it', 'was', 'UA', 'flight', '1001', '!', 'Now', 'I', "'m", 'currently', 'stuck', 'in', 'Portland', 'because', 'I', 'missed', 'my', 'ride', 'because', 'of', 'the', '3', 'hour', 'delay', '.', '#', 'GetMartyHome']
# VADER OUTPUT {'neg': 0.263, 'neu': 0.737, 'pos': 0.0, 'compound': -0.6996}
#
# INPUT SENTENCE @SouthwestAir nice touch on the passbook integration!
# INPUT TO VADER ['@SouthwestAir', 'nice', 'touch', 'on', 'the', 'passbook', 'integration', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.66, 'pos': 0.34, 'compound': 0.4753}
#
# INPUT SENTENCE Keep it up :) @AmericanAir
# INPUT TO VADER ['Keep', 'it', 'up', ':)', '@AmericanAir']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.571, 'pos': 0.429, 'compound': 0.4588}
#
# INPUT SENTENCE thank you so much!!
# INPUT TO VADER ['@AmericanAir', 'DONE', '!', '!', 'thank', 'you', 'so', 'much', '!', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'compound': 0.5673}
#
# INPUT SENTENCE @USAirways any chance of a travel advisory or DCA this weekend?
# INPUT TO VADER ['@USAirways', 'any', 'chance', 'of', 'a', 'travel', 'advisory', 'or', 'DCA', 'this', 'weekend', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.818, 'pos': 0.182, 'compound': 0.25}
#
# INPUT SENTENCE But great agents in savannah!
# INPUT TO VADER ['@JetBlue', 'keep', 'going', 'back', 'and', 'forth', 'with', 'being', 'able', 'to', 'board', 'and', 'then', 'not', '.', 'But', 'great', 'agents', 'in', 'savannah', '!']
# VADER OUTPUT {'neg': 0.208, 'neu': 0.792, 'pos': 0.0, 'compound': -0.694}
#
# INPUT SENTENCE "@JetBlue Flight 152 (N559JB) ""Here's Looking at Blue Kid"" departs @MCO enroute to @BostonLogan http://t.co/qeaDA92MW6"
# INPUT TO VADER ['"', '@JetBlue', 'Flight', '152', '(', 'N559JB', ')', '"', '"', 'Here', "'s", 'Looking', 'at', 'Blue', 'Kid', '"', '"', 'departs', '@MCO', 'enroute', 'to', '@BostonLogan', 'http://t.co/qeaDA92MW6', '"']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united diverged to Burlington
# INPUT TO VADER ['"', '@united', 'diverged', 'to', 'Burlington']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united thank you for taking care of my mom and reFlight Booking Problems her flight in phl.
# INPUT TO VADER ['@united', 'thank', 'you', 'for', 'taking', 'care', 'of', 'my', 'mom', 'and', 'reFlight', 'Booking', 'Problems', 'her', 'flight', 'in', 'phl', '.']
# VADER OUTPUT {'neg': 0.121, 'neu': 0.625, 'pos': 0.254, 'compound': 0.4588}
#
# INPUT SENTENCE @united thanks we'll be in touch!
# INPUT TO VADER ['@united', 'thanks', 'we', "'ll", 'be', 'in', 'touch', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.653, 'pos': 0.347, 'compound': 0.4926}
#
# INPUT SENTENCE @united line full of worried customers and guy at desk says so sorry you will have to take care of your problems Late Flightr I don't have time.
# INPUT TO VADER ['@united', 'line', 'full', 'of', 'worried', 'customers', 'and', 'guy', 'at', 'desk', 'says', 'so', 'sorry', 'you', 'will', 'have', 'to', 'take', 'care', 'of', 'your', 'problems', 'Late', 'Flightr', 'I', 'do', "n't", 'have', 'time', '.']
# VADER OUTPUT {'neg': 0.196, 'neu': 0.709, 'pos': 0.095, 'compound': -0.3488}
#
# INPUT SENTENCE @united my flight is Late Flight due to mechanical issues 3 of 4 flights in past 10 days!
# INPUT TO VADER ['@united', 'my', 'flight', 'is', 'Late', 'Flight', 'due', 'to', 'mechanical', 'issues', '3', 'of', '4', 'flights', 'in', 'past', '10', 'days', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united please arrange someone at the arriving gate of flight 5957 to Chicago for either a refund or first class upgrade
# INPUT TO VADER ['@united', 'please', 'arrange', 'someone', 'at', 'the', 'arriving', 'gate', 'of', 'flight', '5957', 'to', 'Chicago', 'for', 'either', 'a', 'refund', 'or', 'first', 'class', 'upgrade']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.892, 'pos': 0.108, 'compound': 0.3182}
#
# INPUT SENTENCE each united employee
# INPUT TO VADER ['"', '@united', 'Not', 'appropriate', 'to', 'ask', 'in', 'public', '(', 'hence', 'the', 'dm', ')', '.', 'each', 'united', 'employee']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.811, 'pos': 0.189, 'compound': 0.4215}
#
# INPUT SENTENCE On a good note
# INPUT TO VADER ['"', '@USAirways', 'thanks', 'for', 'the', 'reply', '.', 'On', 'a', 'good', 'note']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.7003}
#
# INPUT SENTENCE http://t.co/dN1if2cGwE
# INPUT TO VADER ['@United', 'is', 'freaking', 'worthless', '.', 'I', 'hate', 'this', 'airline', '.', 'http://t.co/dN1if2cGwE']
# VADER OUTPUT {'neg': 0.653, 'neu': 0.347, 'pos': 0.0, 'compound': -0.8555}
#
# INPUT SENTENCE "@united if you're going to Cancelled Flight flights today
# INPUT TO VADER ['"', '@united', 'if', 'you', "'re", 'going', 'to', 'Cancelled', 'Flight', 'flights', 'today']
# VADER OUTPUT {'neg': 0.182, 'neu': 0.818, 'pos': 0.0, 'compound': -0.25}
#
# INPUT SENTENCE @AmericanAir drop me a follow I need help
# INPUT TO VADER ['@AmericanAir', 'drop', 'me', 'a', 'follow', 'I', 'need', 'help']
# VADER OUTPUT {'neg': 0.239, 'neu': 0.455, 'pos': 0.307, 'compound': 0.1531}
#
# INPUT SENTENCE http://t.co/mpi4yuo9jR” Oh word!!!!??????
# INPUT TO VADER ['“', '@JetBlue', ':', 'Our', 'fleet', "'s", 'on', 'fleek', '.', 'http://t.co/mpi4yuo9jR', '”', 'Oh', 'word', '!', '!', '!', '!', '?', '?', '?', '?', '?', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@VirginAmerica has getaway deals through May
# INPUT TO VADER ['"', '@VirginAmerica', 'has', 'getaway', 'deals', 'through', 'May']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir iPhone App Adds Passbook Support #Airlines #Travel http://t.co/lJzDTHD9Bv
# INPUT TO VADER ['@SouthwestAir', 'iPhone', 'App', 'Adds', 'Passbook', 'Support', '#', 'Airlines', '#', 'Travel', 'http://t.co/lJzDTHD9Bv']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.4019}
#
# INPUT SENTENCE Just a second.
# INPUT TO VADER ['@SouthwestAir', 'sure', 'can', '!', 'Just', 'a', 'second', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.607, 'pos': 0.393, 'compound': 0.3802}
#
# INPUT SENTENCE Send Bloody Mary's to row 27!!!
# INPUT TO VADER ['@USAirways', 'made', 'it', '!', '!', '!', 'Send', 'Bloody', 'Mary', "'s", 'to', 'row', '27', '!', '!', '!']
# VADER OUTPUT {'neg': 0.311, 'neu': 0.689, 'pos': 0.0, 'compound': -0.6209}
#
# INPUT SENTENCE Pretty ridiculous.
# INPUT TO VADER ['@united', 'Connection', 'at', 'ORD', 'was', 'on', 'the', 'exact', 'same', 'plane', 'again', '.', 'Checked', 'carry', '-', 'on', 'was', 'apparently', 'taken', 'off', '&', 'amp', ';', 'left', 'in', 'Chicago', '.', 'Pretty', 'ridiculous', '.']
# VADER OUTPUT {'neg': 0.09, 'neu': 0.794, 'pos': 0.116, 'compound': 0.1779}
#
# INPUT SENTENCE Good #customerservice is dead."
# INPUT TO VADER ['"', '@united', 'Cancelled', 'Flights', 'flt', 'from', 'EWR', '.', '"', '"', 'No', 'crew""', '.', 'Tells', 'wife', '&', 'amp', ';', '4', 'yr', 'old', 'to', '"', '"', 'get', 'to', 'NY', 'to', 'catch', '@AirCanada', '"', '"', 'to', 'YYZ', '!', 'Good', '#', 'customerservice', 'is', 'dead', '.', '"']
# VADER OUTPUT {'neg': 0.261, 'neu': 0.653, 'pos': 0.086, 'compound': -0.7088}
#
# INPUT SENTENCE "@VirginAmerica I rang
# INPUT TO VADER ['"', '@VirginAmerica', 'I', 'rang']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Can we combine res?
# INPUT TO VADER ['@united', 'assume', 'those', 'benefits', 'only', 'apply', 'to', 'my', 'own', 'reservation', '.', 'Any', 'way', 'my', 'partner', '(', 'on', 'diff', 'res', ')', 'can', 'use', 'them', '?', 'Can', 'we', 'combine', 'res', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.886, 'pos': 0.114, 'compound': 0.4515}
#
# INPUT SENTENCE I am being told that I am asking for a refund on a used ticket on a flight that got Cancelled Flightled how is the ticket used?
# INPUT TO VADER ['@united', 'contd', '...', 'I', 'am', 'being', 'told', 'that', 'I', 'am', 'asking', 'for', 'a', 'refund', 'on', 'a', 'used', 'ticket', 'on', 'a', 'flight', 'that', 'got', 'Cancelled', 'Flightled', 'how', 'is', 'the', 'ticket', 'used', '?']
# VADER OUTPUT {'neg': 0.077, 'neu': 0.923, 'pos': 0.0, 'compound': -0.25}
#
# INPUT SENTENCE Never ever flying United again #joke
# INPUT TO VADER ['@united', 'you', 'have', 'now', 'lost', 'my', 'bag', '.', 'Never', 'ever', 'flying', 'United', 'again', '#', 'joke']
# VADER OUTPUT {'neg': 0.275, 'neu': 0.594, 'pos': 0.131, 'compound': -0.3468}
#
# INPUT SENTENCE @united if I was rebooked do I have to pick up my luggage?
# INPUT TO VADER ['@united', 'if', 'I', 'was', 'rebooked', 'do', 'I', 'have', 'to', 'pick', 'up', 'my', 'luggage', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Super professional!
# INPUT TO VADER ['@USAirways', 'Best', 'GAgent', 'in', 'a', 'long', 'time', '-', 'Danny', 'B.', 'for', 'US628', 'DFW', '-', 'CLT', '.', 'Appreciated', 'how', 'up', 'to', 'date', 'he', 'kept', 'us', 'during', 'irrops', '.', 'Super', 'professional', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.642, 'pos': 0.358, 'compound': 0.9134}
#
# INPUT SENTENCE Or at least prepared with a gate when we land!
# INPUT TO VADER ['@united', 'too', 'big', 'to', 'properly', 'manage', 'flight', 'times', '.', 'There', 'is', 'such', 'a', 'thing', 'as', 'being', 'on', 'time', '.', 'Or', 'at', 'least', 'prepared', 'with', 'a', 'gate', 'when', 'we', 'land', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.916, 'pos': 0.084, 'compound': 0.2942}
#
# INPUT SENTENCE And to @PamGrout for positive thoughts.
# INPUT TO VADER ['@JetBlue', 'Thank', 'you', 'for', 'the', 'service', 'credit', '.', 'And', 'to', '@PamGrout', 'for', 'positive', 'thoughts', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.535, 'pos': 0.465, 'compound': 0.8271}
#
# INPUT SENTENCE "@united Late Flight 2014 and 2015 are huge step towards decline in service
# INPUT TO VADER ['"', '@united', 'Late', 'Flight', '2014', 'and', '2015', 'are', 'huge', 'step', 'towards', 'decline', 'in', 'service']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.3182}
#
# INPUT SENTENCE Denver to LAX and it's wonderful!!!
# INPUT TO VADER ['@united', 'I', 'think', 'this', 'is', 'the', 'best', 'first', 'class', 'I', 'have', 'ever', 'gotten', '!', '!', ' ', 'Denver', 'to', 'LAX', 'and', 'it', "'s", 'wonderful', '!', '!', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.638, 'pos': 0.362, 'compound': 0.877}
#
# INPUT SENTENCE "@VirginAmerica I spoke with a representative that offered no solution
# INPUT TO VADER ['"', '@VirginAmerica', 'I', 'spoke', 'with', 'a', 'representative', 'that', 'offered', 'no', 'solution']
# VADER OUTPUT {'neg': 0.21, 'neu': 0.571, 'pos': 0.219, 'compound': 0.0258}
#
# INPUT SENTENCE Can I DM you the info?
# INPUT TO VADER ['@united', 'ok', '.', 'Can', 'I', 'DM', 'you', 'the', 'info', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'compound': 0.296}
#
# INPUT SENTENCE @united if I miss the #Oscars I'll never fly united again
# INPUT TO VADER ['@united', 'if', 'I', 'miss', 'the', '#', 'Oscars', 'I', "'ll", 'never', 'fly', 'united', 'again']
# VADER OUTPUT {'neg': 0.33, 'neu': 0.67, 'pos': 0.0, 'compound': -0.4464}
#
# INPUT SENTENCE @JetBlue is definitely my new favorite airline.
# INPUT TO VADER ['@JetBlue', 'is', 'definitely', 'my', 'new', 'favorite', 'airline', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.467, 'pos': 0.533, 'compound': 0.6908}
#
# INPUT SENTENCE Thanks!
# INPUT TO VADER ['@USAirways', 'looks', 'like', 'our', 'bag', 'has', 'been', 'rescued', '.', 'Thanks', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.414, 'pos': 0.586, 'compound': 0.8172}
#
# INPUT SENTENCE All good now.
# INPUT TO VADER ['@united', 'Was', 'able', 'to', 'send', 'the', 'DM', '.', 'All', 'good', 'now', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.4404}
#
# INPUT SENTENCE united has no baby meals
# INPUT TO VADER ['@united', 'forces', 'us', 'to', 'check', 'our', 'baby', 'bag', 'on', 'overbooked', 'flight', 'complains', 'to', 'wife', 'that', 'we', 'need', 'to', 'much', 'for', 'our', 'baby', '..', 'united', 'has', 'no', 'baby', 'meals']
# VADER OUTPUT {'neg': 0.147, 'neu': 0.767, 'pos': 0.086, 'compound': -0.25}
#
# INPUT SENTENCE @AmericanAir OK I will call them likely tmrw UK time to question the process getting the change charge reversed due to a bereavement
# INPUT TO VADER ['@AmericanAir', 'OK', 'I', 'will', 'call', 'them', 'likely', 'tmrw', 'UK', 'time', 'to', 'question', 'the', 'process', 'getting', 'the', 'change', 'charge', 'reversed', 'due', 'to', 'a', 'bereavement']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.4466}
#
# INPUT SENTENCE You made the difficult weather days proficient and enjoyable.
# INPUT TO VADER ['@united', 'Thank', 'you', 'for', 'the', 'new', 'Club', 'at', "O'Hare", '.', 'Very', 'comfortable', '.', 'You', 'made', 'the', 'difficult', 'weather', 'days', 'proficient', 'and', 'enjoyable', '.']
# VADER OUTPUT {'neg': 0.091, 'neu': 0.582, 'pos': 0.327, 'compound': 0.7574}
#
# INPUT SENTENCE Mind if I ask
# INPUT TO VADER ['"', '@AmericanAir', 'Thanks', 'gang', '!', 'Mind', 'if', 'I', 'ask']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.61, 'pos': 0.39, 'compound': 0.4926}
#
# INPUT SENTENCE Thanks!
# INPUT TO VADER ['@USAirways', 'FYI', 'your', 'customer', 'service', 'rep', 'Carol', 'is', 'an', 'absolute', 'delight', '.', 'So', 'pleasant', 'to', 'with', 'with', 'and', 'rebooked', 'me', 'in', 'lightning', 'speed', '!', 'Thanks', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.584, 'pos': 0.416, 'compound': 0.9261}
#
# INPUT SENTENCE ^EY”
# INPUT TO VADER ['Yes', '!', '!', 'Thanks', 'so', 'much', '!', '!', '!', '💜', '“', '@united', ':', '@whitterbug', 'We', 'see', 'you', 'spoke', 'with', 'our', 'Reservations', 'team', 'and', 'they', "'ve", 'reinstated', 'the', 'flight', '.', 'Thanks', '.', '^EY', '”']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.663, 'pos': 0.337, 'compound': 0.8647}
#
# INPUT SENTENCE http://t.co/2nY5TuXFqf
# INPUT TO VADER ['@united', 'Why', 'do', 'I', 'have', 'to', 'give', 'up', 'my', 'leg', 'room', 'so', 'these', '4', 'people', '(', 'not', 'in', 'my', 'row', ')', 'can', 'fill', 'the', 'bin', '?', ' ', 'Pls', 'start', 'charging', '.', 'http://t.co/2nY5TuXFqf']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.949, 'pos': 0.051, 'compound': 0.0772}
#
# INPUT SENTENCE and how does one obtain this companion pass?
# INPUT TO VADER ['@SouthwestAir', '...', 'and', 'how', 'does', 'one', 'obtain', 'this', 'companion', 'pass', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united SATURDAY this morning Man dies from Ebola http://t.co/hXVVIS0VWw
# INPUT TO VADER ['@united', 'SATURDAY', 'this', 'morning', 'Man', 'dies', 'from', 'Ebola', 'http://t.co/hXVVIS0VWw']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "Thank you
# INPUT TO VADER ['"', 'Thank', 'you']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'compound': 0.3612}
#
# INPUT SENTENCE "@JetBlue can your people working this contact me
# INPUT TO VADER ['"', '@JetBlue', 'can', 'your', 'people', 'working', 'this', 'contact', 'me']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Or we could just delay :/
# INPUT TO VADER ['@united', 'why', 'do', "n't", 'you', 'de', '-', 'ice', 'while', 'the', 'plane', 'sits', 'there', 'with', 'no', 'one', 'in', 'it', 'for', '2', 'hours', '?', '?', 'Or', 'we', 'could', 'just', 'delay', ':/']
# VADER OUTPUT {'neg': 0.248, 'neu': 0.752, 'pos': 0.0, 'compound': -0.7399}
#
# INPUT SENTENCE #UnitedAirlines
# INPUT TO VADER ['.@united', 'Let', 'us', 'know', 'when', 'you', 'find', 'everyone', "'s", 'luggage', '.', 'Thanks', '.', '#', 'UnitedAirlines']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'compound': 0.4404}
#
# INPUT SENTENCE "@united so going forward
# INPUT TO VADER ['"', '@united', 'so', 'going', 'forward']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE sent
# INPUT TO VADER ['“', '@USAirways', ':', '@AnnetteNaif', 'We', 'appreciate', 'the', '#', 'shoutout', 'for', 'Roberto', '.', 'DM', 'your', 'confirmation', 'code', 'so', 'we', 'can', 'forward', 'your', 'kind', 'words', '.', '”', 'sent']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.747, 'pos': 0.253, 'compound': 0.7269}
#
# INPUT SENTENCE http://t.co/dSDEbodmEL
# INPUT TO VADER ['👉', '🚪', 'RT', '@JetBlue', ':', 'Our', 'fleet', "'s", 'on', 'fleek', '.', 'http://t.co/dSDEbodmEL']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE http://t.co/bNgpli8JT6
# INPUT TO VADER ['@united', 'have', 'you', 'inspected', 'the', 'picture', '?', 'routine', 'aircraft', 'check', 'while', 'on', 'his', 'cell', 'phone', '?', 'What', 'will', 'the', 'FAA', '&', 'amp', ';', 'NYT', 'say', '?', 'http://t.co/bNgpli8JT6']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united this is atrocious customer service.
# INPUT TO VADER ['@united', 'this', 'is', 'atrocious', 'customer', 'service', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@AmericanAir sure
# INPUT TO VADER ['"', '@AmericanAir', 'sure']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'compound': 0.3182}
#
# INPUT SENTENCE I have to be refunded whenever I get at my final destination or not!
# INPUT TO VADER ['@united', 'ridiculous', '!', 'I', 'have', 'to', 'be', 'refunded', 'whenever', 'I', 'get', 'at', 'my', 'final', 'destination', 'or', 'not', '!']
# VADER OUTPUT {'neg': 0.192, 'neu': 0.808, 'pos': 0.0, 'compound': -0.4738}
#
# INPUT SENTENCE "@SouthwestAir oops
# INPUT TO VADER ['"', '@SouthwestAir', 'oops']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Why do I have to play for hotel tonight in #ewr?
# INPUT TO VADER ['@united', 'Late', 'Flight', 'crew', 'into', '#', 'btv', 'last', 'nite', 'delayed', 'todays', 'flt', '.', 'Will', 'miss', 'connection', 'to', '#', 'cun', '.', 'Why', 'do', 'I', 'have', 'to', 'play', 'for', 'hotel', 'tonight', 'in', '#', 'ewr', '?']
# VADER OUTPUT {'neg': 0.121, 'neu': 0.796, 'pos': 0.083, 'compound': -0.0258}
#
# INPUT SENTENCE "@AmericanAir I have a couple questions for you
# INPUT TO VADER ['"', '@AmericanAir', 'I', 'have', 'a', 'couple', 'questions', 'for', 'you']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "Nice RT @VirginAmerica: The man of steel might be faster
# INPUT TO VADER ['"', 'Nice', 'RT', '@VirginAmerica', ':', 'The', 'man', 'of', 'steel', 'might', 'be', 'faster']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.4215}
#
# INPUT SENTENCE @SouthwestAir how are flights looking for tomorrow morning from #Nashville (BNA) to Fort Lauderdale (FLL) ?!
# INPUT TO VADER ['@SouthwestAir', 'how', 'are', 'flights', 'looking', 'for', 'tomorrow', 'morning', 'from', '#', 'Nashville', '(', 'BNA', ')', 'to', 'Fort', 'Lauderdale', '(', 'FLL', ')', '?', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE this experience just keeps getting worse and worse
# INPUT TO VADER ['@united', 'now', 'been', 'on', 'board', 'with', 'no', 'movement', 'for', '25', 'min', '...', 'wow', 'this', 'experience', 'just', 'keeps', 'getting', 'worse', 'and', 'worse']
# VADER OUTPUT {'neg': 0.288, 'neu': 0.582, 'pos': 0.13, 'compound': -0.5574}
#
# INPUT SENTENCE Great people at your call center!
# INPUT TO VADER ['@USAirways', ' ', 'thank', 'you', '!', 'Glad', 'to', 'be', 'heading', 'home', '!', 'Great', 'people', 'at', 'your', 'call', 'center', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.512, 'pos': 0.488, 'compound': 0.8879}
#
# INPUT SENTENCE Im so Flight Booking Problems my next flight with you!
# INPUT TO VADER ['@JetBlue', 'here', 'in', 'Austin', 'I', 'saw', 'the', 'water', 'bottles', '&', 'amp', ';', 'snacks', '@', 'the', 'desk', 'for', 'your', 'waiting', 'passengers', '!', 'I', 'm', 'so', 'Flight', 'Booking', 'Problems', 'my', 'next', 'flight', 'with', 'you', '!']
# VADER OUTPUT {'neg': 0.129, 'neu': 0.871, 'pos': 0.0, 'compound': -0.5496}
#
# INPUT SENTENCE "@united your first class is a joke
# INPUT TO VADER ['"', '@united', 'your', 'first', 'class', 'is', 'a', 'joke']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.694, 'pos': 0.306, 'compound': 0.296}
#
# INPUT SENTENCE Hope to be flying with you guys soon!
# INPUT TO VADER ['@JetBlue', 'okay', 'thanks', '.', 'Hope', 'to', 'be', 'flying', 'with', 'you', 'guys', 'soon', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.7901}
#
# INPUT SENTENCE "@united enough already with the poor service
# INPUT TO VADER ['"', '@united', 'enough', 'already', 'with', 'the', 'poor', 'service']
# VADER OUTPUT {'neg': 0.341, 'neu': 0.659, 'pos': 0.0, 'compound': -0.4767}
#
# INPUT SENTENCE @united I wasn't asking for a full refund but delaying me 3 hours and giving no reason should be enough to give partial credit
# INPUT TO VADER ['@united', 'I', 'was', "n't", 'asking', 'for', 'a', 'full', 'refund', 'but', 'delaying', 'me', '3', 'hours', 'and', 'giving', 'no', 'reason', 'should', 'be', 'enough', 'to', 'give', 'partial', 'credit']
# VADER OUTPUT {'neg': 0.099, 'neu': 0.671, 'pos': 0.23, 'compound': 0.5719}
#
# INPUT SENTENCE @JetBlue thank you!!
# INPUT TO VADER ['@JetBlue', 'thank', 'you', '!', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.393, 'pos': 0.607, 'compound': 0.4738}
#
# INPUT SENTENCE Thank you!!
# INPUT TO VADER ['@united', 'your', 'agents', '(', 'and', 'service', ')', 'on', 'my', 'weekend', 'trip', 'have', 'been', 'AMAZING', '!', '!', '!', 'Thank', 'you', '!', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.594, 'pos': 0.406, 'compound': 0.8482}
#
# INPUT SENTENCE As of yet
# INPUT TO VADER ['"', '@united', 'well', '.', 'As', 'of', 'yet']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.2732}
#
# INPUT SENTENCE Thank you.
# INPUT TO VADER ['@United', 'Claudia', 'in', 'IAH', 'terminal', 'b', 'travel', 'assistance', 'has', 'me', 'all', 'set', '.', 'Great', 'service', '.', 'Thank', 'you', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.663, 'pos': 0.337, 'compound': 0.765}
#
# INPUT SENTENCE @united another awesome new plane flight 1584 and extremely nice Captain Steve Connolly.
# INPUT TO VADER ['@united', 'another', 'awesome', 'new', 'plane', 'flight', '1584', 'and', 'extremely', 'nice', 'Captain', 'Steve', 'Connolly', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.605, 'pos': 0.395, 'compound': 0.8016}
#
# INPUT SENTENCE NEVER AGAIN with @united
# INPUT TO VADER ['@united', 'WTF', '!', '?', '!', '?', 'Delay', 'after', 'delay', '.', '15', 'hours', 'YVR', 'to', 'SAN', '?', 'Unacceptable', '.', 'Flight', 'Crew', 'Availability', 'is', 'to', 'blame', '?', 'NEVER', 'AGAIN', 'with', '@united']
# VADER OUTPUT {'neg': 0.501, 'neu': 0.499, 'pos': 0.0, 'compound': -0.944}
#
# INPUT SENTENCE @SouthwestAir yes please
# INPUT TO VADER ['@SouthwestAir', 'yes', 'please']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.167, 'pos': 0.833, 'compound': 0.6124}
#
# INPUT SENTENCE "@united I was insulted
# INPUT TO VADER ['"', '@united', 'I', 'was', 'insulted']
# VADER OUTPUT {'neg': 0.623, 'neu': 0.377, 'pos': 0.0, 'compound': -0.5106}
#
# INPUT SENTENCE @virginamerica may start service to Hawaii from #SanFrancisco this year http://t.co/yPo7nYpRZl #biztravel
# INPUT TO VADER ['@virginamerica', 'may', 'start', 'service', 'to', 'Hawaii', 'from', '#', 'SanFrancisco', 'this', 'year', 'http://t.co/yPo7nYpRZl', '#', 'biztravel']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united @czamkoff It's all about profit
# INPUT TO VADER ['"', '@united', '@czamkoff', 'It', "'s", 'all', 'about', 'profit']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.4404}
#
# INPUT SENTENCE Left us in the cold in DEN.
# INPUT TO VADER ['@united', '#', 'UnitedAirlines', 'Pls', 'Fix', '#', 'AspenBaggageFail', 'issues', '.', 'Had', 'to', 'pay', 'my', 'own', 'way', 'to', '#', 'Aspen', 'after', 'flight', 'Cancelled', 'Flight', '.', 'Left', 'us', 'in', 'the', 'cold', 'in', 'DEN', '.']
# VADER OUTPUT {'neg': 0.127, 'neu': 0.824, 'pos': 0.049, 'compound': -0.2732}
#
# INPUT SENTENCE #ua1523
# INPUT TO VADER ['@united', 'bad', 'idea', 'to', 'let', '200', 'people', 'back', 'on', 'the', 'terminal', 'with', 'food', 'vouchers', 'but', 'allow', 'only', '15', 'minutes', 'to', 'get', 'anything', '.', ' ', 'Long', 'lines', '!', '!', '#', 'ua1523']
# VADER OUTPUT {'neg': 0.08, 'neu': 0.816, 'pos': 0.104, 'compound': 0.1739}
#
# INPUT SENTENCE "@united what
# INPUT TO VADER ['"', '@united', 'what']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE contact http://t.co/aQjn4HwNaC  we negotiate resolutions for You!
# INPUT TO VADER ['@JetBlue', 'Airline', 'trouble', 'this', 'winter', '&', 'amp', ';', 'not', 'getting', 'good', 'customer', 'service', '?', 'contact', 'http://t.co/aQjn4HwNaC', ' ', 'we', 'negotiate', 'resolutions', 'for', 'You', '!']
# VADER OUTPUT {'neg': 0.252, 'neu': 0.748, 'pos': 0.0, 'compound': -0.6595}
#
# INPUT SENTENCE @AmericanAir @dfwairport you 2 together are the best part of flying!
# INPUT TO VADER ['@AmericanAir', '@dfwairport', 'you', '2', 'together', 'are', 'the', 'best', 'part', 'of', 'flying', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.6696}
#
# INPUT SENTENCE #veryimportantproject
# INPUT TO VADER ['@AmericanAir', '@cityandsand', 'we', "'re", 'trying', 'to', 'coordinate', 'an', 'airport', 'hand', '-', 'off', 'of', 'Nutella', '!', '#', 'veryimportantproject']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.788, 'pos': 0.212, 'compound': 0.5411}
#
# INPUT SENTENCE http://t.co/aypyaDUY6a
# INPUT TO VADER ['@SouthwestAir', 'Never', 'felt', 'better', 'taken', 'care', 'of', '!', 'Indian', 'aunties', 'are', 'the', 'gold', 'standard', '.', 'Thanks', 'Aruna', '!', 'http://t.co/aypyaDUY6a']
# VADER OUTPUT {'neg': 0.109, 'neu': 0.589, 'pos': 0.303, 'compound': 0.646}
#
# INPUT SENTENCE Although the wait was long due to weather r/scheduling
# INPUT TO VADER ['"', '@SouthwestAir', 'Although', 'the', 'wait', 'was', 'long', 'due', 'to', 'weather', 'r', '/', 'scheduling']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Pleased to be a Premier Platinum
# INPUT TO VADER ['@united', 'Pleased', 'to', 'be', 'a', 'Premier', 'Platinum']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'compound': 0.4404}
#
# INPUT SENTENCE @AmericanAir is that the flight for tomorrow?
# INPUT TO VADER ['@AmericanAir', 'is', 'that', 'the', 'flight', 'for', 'tomorrow', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Another awful experience and Victoria at the check in desk in STL could not have been more rude and condescending.
# INPUT TO VADER ['@united', 'Another', 'awful', 'experience', 'and', 'Victoria', 'at', 'the', 'check', 'in', 'desk', 'in', 'STL', 'could', 'not', 'have', 'been', 'more', 'rude', 'and', 'condescending', '.']
# VADER OUTPUT {'neg': 0.249, 'neu': 0.751, 'pos': 0.0, 'compound': -0.7425}
#
# INPUT SENTENCE @united thanks
# INPUT TO VADER ['@united', 'thanks']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
#
# INPUT SENTENCE Thank you for providing one bright spot in a frustrating situation.
# INPUT TO VADER ['@SouthwestAir', 'Karen', 'with', 'customer', 'service', 'was', 'very', 'helpful', '.', 'Thank', 'you', 'for', 'providing', 'one', 'bright', 'spot', 'in', 'a', 'frustrating', 'situation', '.']
# VADER OUTPUT {'neg': 0.113, 'neu': 0.545, 'pos': 0.342, 'compound': 0.707}
#
# INPUT SENTENCE "@united boarding was decent
# INPUT TO VADER ['"', '@united', 'boarding', 'was', 'decent']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE keep your paper work ready and don't delay our flights(#1585)and meetings @ChooseChicago
# INPUT TO VADER ['@united', 'common', '!', '!', 'keep', 'your', 'paper', 'work', 'ready', 'and', 'do', "n't", 'delay', 'our', 'flights(#1585)and', 'meetings', '@ChooseChicago']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.72, 'pos': 0.28, 'compound': 0.6182}
#
# INPUT SENTENCE I appreciate you working with me
# INPUT TO VADER ['@united', 'thank', 'you', 'for', 'listening', 'to', 'my', 'compliant', 'and', 'doing', 'the', 'right', 'thing', '.', 'I', 'appreciate', 'you', 'working', 'with', 'me']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'compound': 0.6369}
#
# INPUT SENTENCE Unacceptable
# INPUT TO VADER ['@united', 'so', 'disgusted', 'and', 'disappointed', 'with', 'united', 'airlines', 'luggage', 'policies', 'and', 'attitude', 'toward', 'musicians', '.', 'Unacceptable']
# VADER OUTPUT {'neg': 0.422, 'neu': 0.461, 'pos': 0.117, 'compound': -0.8051}
#
# INPUT SENTENCE Not waste their time?!
# INPUT TO VADER ['@united', 'thanks', 'KP', '.', ' ', 'What', "'s", 'going', 'on', 'w/4840', 'tonight', '.', ' ', 'Bad', 'update', 'online', 'and', 'phone', '.', 'Ca', "n't", 'u', 'give', 'customers', 'good', 'info', '.', 'Not', 'waste', 'their', 'time', '?', '!']
# VADER OUTPUT {'neg': 0.197, 'neu': 0.636, 'pos': 0.166, 'compound': -0.242}
#
# INPUT SENTENCE @AmericanAir followback
# INPUT TO VADER ['@AmericanAir', 'followback']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@VirginAmerica Anytime
# INPUT TO VADER ['"', '@VirginAmerica', 'Anytime']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways in a few weeks
# INPUT TO VADER ['@USAirways', 'in', 'a', 'few', 'weeks']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue Seems very likely.
# INPUT TO VADER ['@JetBlue', 'Seems', 'very', 'likely', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @AmericanAir can I send you my trusted traveler ID to add to my reservation for tsa pre?
# INPUT TO VADER ['@AmericanAir', 'can', 'I', 'send', 'you', 'my', 'trusted', 'traveler', 'ID', 'to', 'add', 'to', 'my', 'reservation', 'for', 'tsa', 'pre', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'compound': 0.4767}
#
# INPUT SENTENCE Was told ""we can't find a supervisor."""
# INPUT TO VADER ['"', '@united', 'once', 'he', 'found', 'out', 'we', 'had', 'a', 'problem', 'he', 'avoided', 'me', 'like', 'the', 'plague', '.', 'Was', 'told', '"', '"', 'we', 'ca', "n't", 'find', 'a', 'supervisor', '.', '"', '"', '"']
# VADER OUTPUT {'neg': 0.199, 'neu': 0.703, 'pos': 0.098, 'compound': -0.3818}
#
# INPUT SENTENCE NEVER AGAIN!
# INPUT TO VADER ['@united', 'screws', 'up', 'again', '...', 'to', 'be', 'expected', '!', 'NEVER', 'AGAIN', '!']
# VADER OUTPUT {'neg': 0.223, 'neu': 0.777, 'pos': 0.0, 'compound': -0.3786}
#
# INPUT SENTENCE @VirginAmerica your beautiful front-end design is down right now; but it was cool to still book my ticket b/c all your back-end was secure.
# INPUT TO VADER ['@VirginAmerica', 'your', 'beautiful', 'front', '-', 'end', 'design', 'is', 'down', 'right', 'now', ';', 'but', 'it', 'was', 'cool', 'to', 'still', 'book', 'my', 'ticket', 'b', '/', 'c', 'all', 'your', 'back', '-', 'end', 'was', 'secure', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.721, 'pos': 0.279, 'compound': 0.8176}
#
# INPUT SENTENCE r lying how can I help
# INPUT TO VADER ['@united', 'the', 'refund', 'team', 'is', 'far', 'from', 'customer', 'care', 'courtesy', 'they', 'need', 'training', 'on', 'work', 'ethics', '.', 'So', 'it', "'s", 'like', 'sir', 'u', 'r', 'lying', 'how', 'can', 'I', 'help']
# VADER OUTPUT {'neg': 0.098, 'neu': 0.579, 'pos': 0.323, 'compound': 0.7759}
#
# INPUT SENTENCE "@JetBlue's CEO #pilots among ardent fans
# INPUT TO VADER ['"', '@JetBlue', "'s", 'CEO', '#', 'pilots', 'among', 'ardent', 'fans']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.659, 'pos': 0.341, 'compound': 0.4767}
#
# INPUT SENTENCE @SouthwestAir can you help
# INPUT TO VADER ['@SouthwestAir', 'can', 'you', 'help']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.4019}
#
# INPUT SENTENCE @united they did on a delta flight out of LAX which is why I should be compensated for my rental car there.
# INPUT TO VADER ['@united', 'they', 'did', 'on', 'a', 'delta', 'flight', 'out', 'of', 'LAX', 'which', 'is', 'why', 'I', 'should', 'be', 'compensated', 'for', 'my', 'rental', 'car', 'there', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir https://t.co/OQUKSo3s2O subscribe please https://t.co/OQUKSo3s2O
# INPUT TO VADER ['@SouthwestAir', 'https://t.co/OQUKSo3s2O', 'subscribe', 'please', 'https://t.co/OQUKSo3s2O']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.635, 'pos': 0.365, 'compound': 0.3182}
#
# INPUT SENTENCE @united look at this beauty 😉 dc 10 united airlines 😉 http://t.co/MvYoizRPdE
# INPUT TO VADER ['@united', 'look', 'at', 'this', 'beauty', '😉', 'dc', '10', 'united', 'airlines', '😉', 'http://t.co/MvYoizRPdE']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.523, 'pos': 0.477, 'compound': 0.8074}
#
# INPUT SENTENCE "@JetBlue quick question
# INPUT TO VADER ['"', '@JetBlue', 'quick', 'question']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@VirginAmerica can't check in
# INPUT TO VADER ['"', '@VirginAmerica', 'ca', "n't", 'check', 'in']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united After an hour+ wait
# INPUT TO VADER ['"', '@united', 'After', 'an', 'hour+', 'wait']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Deep Vein thrombosis
# INPUT TO VADER ['@united', 'Deep', 'Vein', 'thrombosis']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I’m a small guy
# INPUT TO VADER ['"', '@united', 'I', 'know', '.', 'I', '’m', 'sure', 'you', 'hear', 'it', 'all', 'the', 'time', '—', 'do', 'n’t', 'like', 'the', 'new', 'seats', '.', 'I', '’m', 'a', 'small', 'guy']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.78, 'pos': 0.22, 'compound': 0.5859}
#
# INPUT SENTENCE #ExceptionalService
# INPUT TO VADER ['@JetBlue', 'Thank', 'you', 'Alicia', '!', ' ', '#', 'ExceptionalService']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.589, 'pos': 0.411, 'compound': 0.4199}
#
# INPUT SENTENCE @united #worst2unitedflightsever UA 236 LAS to IAD 2/24 mechanical problems again - took off - had to land for fix - delayed again #wtfodds!
# INPUT TO VADER ['@united', '#', 'worst2unitedflightsever', 'UA', '236', 'LAS', 'to', 'IAD', '2/24', 'mechanical', 'problems', 'again', '-', 'took', 'off', '-', 'had', 'to', 'land', 'for', 'fix', '-', 'delayed', 'again', '#', 'wtfodds', '!']
# VADER OUTPUT {'neg': 0.205, 'neu': 0.795, 'pos': 0.0, 'compound': -0.5983}
#
# INPUT SENTENCE @VirginAmerica to begin Dallas-Austin #flights in April - 88.9 KETR http://t.co/SSUVWwkyHH
# INPUT TO VADER ['@VirginAmerica', 'to', 'begin', 'Dallas', '-', 'Austin', '#', 'flights', 'in', 'April', '-', '88.9', 'KETR', 'http://t.co/SSUVWwkyHH']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Not cool http://t.co/6KpyhckA9l
# INPUT TO VADER ['@united', '-', '3', 'of', '6', 'First', 'seats', 'open', 'on', 'UA5097', '.', 'No', 'upgrades', 'processed', '.', 'Gate', 'agents', '@yyz', 'said', 'their', 'too', 'busy', '.', 'Not', 'cool', 'http://t.co/6KpyhckA9l']
# VADER OUTPUT {'neg': 0.188, 'neu': 0.812, 'pos': 0.0, 'compound': -0.4874}
#
# INPUT SENTENCE Quick
# INPUT TO VADER ['"', '@VirginAmerica', 'thank', 'you', 'for', 'the', 'easy', 'itinerary', 'shift', 'for', 'impending', 'weather', '.', 'Quick']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'compound': 0.6597}
#
# INPUT SENTENCE @SouthwestAir you have open seats on flight 4001 pvd to MCO @ 1215pm today?
# INPUT TO VADER ['@SouthwestAir', 'you', 'have', 'open', 'seats', 'on', 'flight', '4001', 'pvd', 'to', 'MCO', '@', '1215pm', 'today', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Norfolk… http://t.co/TgSLjjN6g0
# INPUT TO VADER ['@southwestair', 'thanks', 'for', 'taking', 'it', 'up', 'a', 'notch', '!', '!', 'leinenkugels', '#', 'craftbeer', '#', 'goodflight', '@', 'Norfolk', '…', 'http://t.co/TgSLjjN6g0']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.759, 'pos': 0.241, 'compound': 0.5399}
#
# INPUT SENTENCE #flythefriendlyskies
# INPUT TO VADER ['@united', 'CDG', '-', 'LAS', '42', 'hours', '.', 'And', 'my', 'luggage', 'is', 'in', 'SFO', '.', 'I', "'ve", 'been', 'wearing', 'the', 'same', 'clothes', 'for', '42', 'hours', '.', 'Thank', 'you', '.', '#', 'flythefriendlyskies']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.898, 'pos': 0.102, 'compound': 0.3612}
#
# INPUT SENTENCE I'm looking at 3/19-3/23
# INPUT TO VADER ['@SouthwestAir', 'are', 'there', 'any', 'flights', 'from', 'MSP', 'to', 'HRL', 'in', 'March', '?', 'I', "'m", 'looking', 'at', '3/19', '-', '3/23']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue to End Partnership with American Express - http://t.co/WhuFmI2Ytd http://t.co/fbTEMFwRsP
# INPUT TO VADER ['@JetBlue', 'to', 'End', 'Partnership', 'with', 'American', 'Express', '-', 'http://t.co/WhuFmI2Ytd', 'http://t.co/fbTEMFwRsP']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@AmericanAir Joanna is wonderful
# INPUT TO VADER ['"', '@AmericanAir', 'Joanna', 'is', 'wonderful']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.448, 'pos': 0.552, 'compound': 0.5719}
#
# INPUT SENTENCE https://t.co/caf2cx3gfi"
# INPUT TO VADER ['"', '@united', '"', '"', 'We', 'like', 'hearing', 'from', 'you', '.', '"', '"', 'So', 'why', 'have', "n't", 'you', 'replied', 'to', 'my', 'tweet', 'and/or', 'email', 'yet', '?', 'https://t.co/caf2cx3gfi', '"']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.878, 'pos': 0.122, 'compound': 0.3612}
#
# INPUT SENTENCE "@SouthwestAir not frustrated
# INPUT TO VADER ['"', '@SouthwestAir', 'not', 'frustrated']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.419, 'pos': 0.581, 'compound': 0.4168}
#
# INPUT SENTENCE I'll send it over when you follow.
# INPUT TO VADER ['@SouthwestAir', 'That', 'would', 'be', 'great', '.', 'Thank', 'you', '!', 'I', "'ll", 'send', 'it', 'over', 'when', 'you', 'follow', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.635, 'pos': 0.365, 'compound': 0.784}
#
# INPUT SENTENCE Unhappy customer.
# INPUT TO VADER ['@united', 'on', '4124', 'arriving', 'two', 'hours', 'Late', 'Flight', 'into', 'CLT', '.', 'Now', 'sitting', 'on', 'the', 'tarmac', 'while', 'they', 'move', 'a', 'plane', 'from', 'the', 'gate', '.', 'Unhappy', 'customer', '.']
# VADER OUTPUT {'neg': 0.109, 'neu': 0.891, 'pos': 0.0, 'compound': -0.4215}
#
# INPUT SENTENCE :)
# INPUT TO VADER ['@JetBlue', 'Flight', 'Booking', 'Problems', 'flights', 'for', 'a', 'DC', 'visit', 'for', 'Easter', 'weekend', 'started', 'difficult', 'but', 'ended', 'well', 'with', 'you', 'guys', '!', 'Big', 'fan', 'here', '.', ':)']
# VADER OUTPUT {'neg': 0.114, 'neu': 0.572, 'pos': 0.314, 'compound': 0.807}
#
# INPUT SENTENCE @JetBlue they were amazing and thank you!
# INPUT TO VADER ['@JetBlue', 'they', 'were', 'amazing', 'and', 'thank', 'you', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.431, 'pos': 0.569, 'compound': 0.7644}
#
# INPUT SENTENCE "@united after 2 days - 1 flight Cancelled Flightled
# INPUT TO VADER ['"', '@united', 'after', '2', 'days', '-', '1', 'flight', 'Cancelled', 'Flightled']
# VADER OUTPUT {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.25}
#
# INPUT SENTENCE @JetBlue any thoughts on waiver of change fees for travel out of Boston this weekend?
# INPUT TO VADER ['@JetBlue', 'any', 'thoughts', 'on', 'waiver', 'of', 'change', 'fees', 'for', 'travel', 'out', 'of', 'Boston', 'this', 'weekend', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@SouthwestAir I have a credit that expires a month before my flight
# INPUT TO VADER ['"', '@SouthwestAir', 'I', 'have', 'a', 'credit', 'that', 'expires', 'a', 'month', 'before', 'my', 'flight']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'compound': 0.3818}
#
# INPUT SENTENCE Thats 3 6+ hour flight delays in 2 weeks
# INPUT TO VADER ['@united', 'that', 's', 'because', 'you', 'did', 'nt', 'read', 'my', 'entire', 'tweet', '.', 'Wife', "'s", '12', 'pm', 'flight', 'is', 'now', 'delayed', 'to', '6:30', '.', ' ', 'That', 's', '3', '6', '+', 'hour', 'flight', 'delays', 'in', '2', 'weeks']
# VADER OUTPUT {'neg': 0.071, 'neu': 0.929, 'pos': 0.0, 'compound': -0.2263}
#
# INPUT SENTENCE "@VirginAmerica - amazing customer  service
# INPUT TO VADER ['"', '@VirginAmerica', '-', 'amazing', 'customer', ' ', 'service']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.441, 'pos': 0.559, 'compound': 0.5859}
#
# INPUT SENTENCE http://t.co/WmX12F33ZC
# INPUT TO VADER ['@JetBlue', 'whatever', 'your', 'lil', '#', 'mint', 'heart', 'desires', '!', 'http://t.co/WmX12F33ZC']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Apply here: http://t.co/jLHM0x7UkB
# INPUT TO VADER ['@SouthwestAir', 'is', 'hiring', 'for', 'their', 'Emerging', 'Leader', 'Development', 'Program-', 'Last', 'day', 'to', 'apply', 'is', 'TODAY', '!', 'Apply', 'here', ':', 'http://t.co/jLHM0x7UkB']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Could you please follow me so i can dm you?
# INPUT TO VADER ['@USAirways', 'Hi', '-', 'i', 'have', 'a', 'travel', 'question', '.', 'Could', 'you', 'please', 'follow', 'me', 'so', 'i', 'can', 'dm', 'you', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.3182}
#
# INPUT SENTENCE Excited to be working with you guys!
# INPUT TO VADER ['@united', 'thank', 'you', '!', 'Excited', 'to', 'be', 'working', 'with', 'you', 'guys', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.593, 'pos': 0.407, 'compound': 0.6688}
#
# INPUT SENTENCE @united give me an email address and I'll send the actually screen shot to you.
# INPUT TO VADER ['@united', 'give', 'me', 'an', 'email', 'address', 'and', 'I', "'ll", 'send', 'the', 'actually', 'screen', 'shot', 'to', 'you', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I mean…it is a great card 😀
# INPUT TO VADER ['@SouthwestAir', 'oh', 'no', 'worries', '.', 'Just', 'have', 'never', 'seen', 'that', 'before', 'until', 'today', '.', 'I', 'mean', '…', 'it', 'is', 'a', 'great', 'card', '😀']
# VADER OUTPUT {'neg': 0.216, 'neu': 0.606, 'pos': 0.177, 'compound': 0.0258}
#
# INPUT SENTENCE @JetBlue with 3 kids and 11 days 340 + doesn't work and it's months in advance
# INPUT TO VADER ['@JetBlue', 'with', '3', 'kids', 'and', '11', 'days', '340', '+', 'does', "n't", 'work', 'and', 'it', "'s", 'months', 'in', 'advance']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Before
# INPUT TO VADER ['"', '@united', 'Your', 'new', 'mileage', 'policy', 'is', 'awful', '.', 'Before']
# VADER OUTPUT {'neg': 0.3, 'neu': 0.7, 'pos': 0.0, 'compound': -0.4588}
#
# INPUT SENTENCE @united involuntarily bumped your passenger and can't guarantee them another flight for three days!
# INPUT TO VADER ['@united', 'involuntarily', 'bumped', 'your', 'passenger', 'and', 'ca', "n't", 'guarantee', 'them', 'another', 'flight', 'for', 'three', 'days', '!']
# VADER OUTPUT {'neg': 0.127, 'neu': 0.873, 'pos': 0.0, 'compound': -0.2575}
#
# INPUT SENTENCE @SouthwestAir if I am enrolled in the ATL companion pass offer and booked 3 flights already before May 17 when can I start using the pass?
# INPUT TO VADER ['@SouthwestAir', 'if', 'I', 'am', 'enrolled', 'in', 'the', 'ATL', 'companion', 'pass', 'offer', 'and', 'booked', '3', 'flights', 'already', 'before', 'May', '17', 'when', 'can', 'I', 'start', 'using', 'the', 'pass', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways Thank you!
# INPUT TO VADER ['@USAirways', 'Thank', 'you', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'compound': 0.4199}
#
# INPUT SENTENCE @SouthwestAir looking for cheap flight to vegas
# ...
# VADER OUTPUT {'neg': 0.0, 'neu': 0.735, 'pos': 0.265, 'compound': 0.6884}
#
# INPUT SENTENCE We'll see about that tomorrow morning when I have to fight for a seat.
# INPUT TO VADER ['@JetBlue', 'Is', 'that', 'a', 'guarantee', '?', 'We', "'ll", 'see', 'about', 'that', 'tomorrow', 'morning', 'when', 'I', 'have', 'to', 'fight', 'for', 'a', 'seat', '.']
# VADER OUTPUT {'neg': 0.133, 'neu': 0.765, 'pos': 0.102, 'compound': -0.1531}
#
# INPUT SENTENCE @USAirways following you now
# INPUT TO VADER ['@USAirways', 'following', 'you', 'now']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE When will u guys learn?
# INPUT TO VADER ['@united', 'Well', 'the', 'bar', 'is', 'set', 'low', '!', 'You', 'guys', 'are', 'really', 'good', 'at', 'the', 'apology', 'game', '!', 'What', 'will', 'change', '?', 'When', 'will', 'u', 'guys', 'learn', '?']
# VADER OUTPUT {'neg': 0.074, 'neu': 0.666, 'pos': 0.261, 'compound': 0.6527}
#
# INPUT SENTENCE "@AmericanAir Next Friday
# INPUT TO VADER ['"', '@AmericanAir', 'Next', 'Friday']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #DestinationDragons
# INPUT TO VADER ['@SouthwestAir', 'when', 'does', 'today', "'s", 'scavenger', 'hunt', 'start', '?', 'I', "'m", 'trying', 'to', 'help', 'my', 'little', 'brother', 'win', '!', '#', 'DestinationDragons']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.697, 'pos': 0.303, 'compound': 0.7589}
#
# INPUT SENTENCE We are finally at the gate.
# INPUT TO VADER ['@JetBlue', 'thank', 'you', '.', 'We', 'are', 'finally', 'at', 'the', 'gate', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'compound': 0.3612}
#
# INPUT SENTENCE As a business owner
# INPUT TO VADER ['"', '@united', 'not', 'even', 'mentioning', 'how', 'rude', 'the', 'customer', 'service', 'was', 'to', 'us', '.', 'As', 'a', 'business', 'owner']
# VADER OUTPUT {'neg': 0.176, 'neu': 0.824, 'pos': 0.0, 'compound': -0.4588}
#
# INPUT SENTENCE Yeah cold
# INPUT TO VADER ['"', '@AmericanAir', '@dfwairport', 'That', "'s", 'DFW', '!', '?', 'OMG', '!', 'Yeah', 'cold']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.715, 'pos': 0.285, 'compound': 0.4184}
#
# INPUT SENTENCE A+ service!
# INPUT TO VADER ['@JetBlue', 'Love', 'you', 'guys', 'sooooooo', 'much', '.', 'Ridiculously', 'appreciated', '!', 'A+', 'service', '!']
# VADER OUTPUT {'neg': 0.137, 'neu': 0.4, 'pos': 0.462, 'compound': 0.7707}
#
# INPUT SENTENCE @VirginAmerica i would like help with some flights please.
# INPUT TO VADER ['@VirginAmerica', 'i', 'would', 'like', 'help', 'with', 'some', 'flights', 'please', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.4, 'pos': 0.6, 'compound': 0.7579}
#
# INPUT SENTENCE @SouthwestAir loving the boarding to go to Chicago #KeepItMovin'
# INPUT TO VADER ['@SouthwestAir', 'loving', 'the', 'boarding', 'to', 'go', 'to', 'Chicago', '#', 'KeepItMovin', "'"]
# VADER OUTPUT {'neg': 0.0, 'neu': 0.672, 'pos': 0.328, 'compound': 0.5994}
#
# INPUT SENTENCE Thank you!
# INPUT TO VADER ['@united', 'the', 'upgrade', 'to', 'first', 'class', 'was', 'a', 'nice', 'way', 'to', 'fix', 'your', 'earlier', 'mistake', '.', 'Thank', 'you', '!']
# VADER OUTPUT {'neg': 0.114, 'neu': 0.619, 'pos': 0.266, 'compound': 0.4926}
#
# INPUT SENTENCE #oscars2016
# INPUT TO VADER ['@united', 'you', "'re", 'my', 'early', 'frontrunner', 'for', 'best', 'airline', '!', '#', 'oscars2016']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.6696}
#
# INPUT SENTENCE Is there a UK number I could try?
# INPUT TO VADER ['@USAirways', 'I', 'am', 'a', 'UK', 'citizen', '.', 'Is', 'there', 'a', 'UK', 'number', 'I', 'could', 'try', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.874, 'pos': 0.126, 'compound': 0.0772}
#
# INPUT SENTENCE "@united has not responded to my various requests for contact numbers
# INPUT TO VADER ['"', '@united', 'has', 'not', 'responded', 'to', 'my', 'various', 'requests', 'for', 'contact', 'numbers']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@AmericanAir I love very much your planes
# INPUT TO VADER ['"', '@AmericanAir', 'I', 'love', 'very', 'much', 'your', 'planes']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.543, 'pos': 0.457, 'compound': 0.6369}
#
# INPUT SENTENCE Thank you!!!
# INPUT TO VADER ['@VirginAmerica', 'and', 'again', '!', 'Another', 'rep', 'kicked', 'butt', '!', 'Naelah', 'represents', 'your', 'team', 'so', 'beautifully', '!', '!', 'Thank', 'you', '!', '!', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.599, 'pos': 0.401, 'compound': 0.8654}
#
# INPUT SENTENCE Haven't heard back and I'm flying this week #disappointed
# INPUT TO VADER ['@VirginAmerica', ' ', 'I', 'applied', 'over', '2', 'weeks', 'ago', '.', 'Have', "n't", 'heard', 'back', 'and', 'I', "'m", 'flying', 'this', 'week', '#', 'disappointed']
# VADER OUTPUT {'neg': 0.181, 'neu': 0.819, 'pos': 0.0, 'compound': -0.4767}
#
# INPUT SENTENCE Never been on ur planes but now I will!!
# INPUT TO VADER ['@VirginAmerica', 'this', 'is', 'too', 'cool', '!', ' ', 'Never', 'been', 'on', 'ur', 'planes', 'but', 'now', 'I', 'will', '!', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.826, 'pos': 0.174, 'compound': 0.3666}
#
# INPUT SENTENCE "@JetBlue yes
# INPUT TO VADER ['"', '@JetBlue', 'yes']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.27, 'pos': 0.73, 'compound': 0.4019}
#
# INPUT SENTENCE It would mean so much to me #DestinationDragons
# INPUT TO VADER ['@SouthwestAir', 'is', 'there', 'anything', 'I', 'can', 'do', 'to', 'get', 'tickets', 'for', '@Imaginedragons', 'at', '@VinylVegas', '?', 'It', 'would', 'mean', 'so', 'much', 'to', 'me', '#', 'DestinationDragons']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #travel #friendlyteam
# INPUT TO VADER ['@USAirways', 'great', 'job', 'today', 'from', 'your', 'team', 'with', 'a', 'challenging', 'weather', 'delay', 'on', 'flight', '1925', 'out', 'of', 'Charlotte', '.', '#', 'travel', '#', 'friendlyteam']
# VADER OUTPUT {'neg': 0.096, 'neu': 0.667, 'pos': 0.237, 'compound': 0.5267}
#
# INPUT SENTENCE @united sent DM's
# INPUT TO VADER ['@united', 'sent', 'DM', "'s"]
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united oh
# INPUT TO VADER ['"', '@united', 'oh']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Apart from being on hold for over 2 hours and having talked to 5 people and the problem still not resolved!
# INPUT TO VADER ['@united', 'Apart', 'from', 'being', 'on', 'hold', 'for', 'over', '2', 'hours', 'and', 'having', 'talked', 'to', '5', 'people', 'and', 'the', 'problem', 'still', 'not', 'resolved', '!']
# VADER OUTPUT {'neg': 0.2, 'neu': 0.8, 'pos': 0.0, 'compound': -0.5439}
#
# INPUT SENTENCE http://t.co/dxn58rxDkS”@jameskraw see.
# INPUT TO VADER ['“', '@JetBlue', ':', 'Our', 'fleet', "'s", 'on', 'fleek', '.', 'http://t.co/dxn58rxDkS”@jameskraw', 'see', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways thanks.
# INPUT TO VADER ['@USAirways', 'thanks', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
#
# INPUT SENTENCE @SouthwestAir  how do you get one?
# INPUT TO VADER ['@SouthwestAir', ' ', 'how', 'do', 'you', 'get', 'one', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Now we are waiting for a flight attendant as one just walked off &amp; left http://t.co/IpaamZT7Z2
# INPUT TO VADER ['@united', 'I', 'would', 'like', 'a', 'supervisor', 'to', 'talk', 'to', '.', 'Now', 'we', 'are', 'waiting', 'for', 'a', 'flight', 'attendant', 'as', 'one', 'just', 'walked', 'off', '&', 'amp', ';', 'left', 'http://t.co/IpaamZT7Z2']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.894, 'pos': 0.106, 'compound': 0.3612}
#
# INPUT SENTENCE @VirginAmerica what is your policy on flying after surgery?
# INPUT TO VADER ['@VirginAmerica', 'what', 'is', 'your', 'policy', 'on', 'flying', 'after', 'surgery', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united it's 9:56
# INPUT TO VADER ['"', '@united', 'it', "'s", '9:56']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@United Right now at Tropic Air in San Pedro
# INPUT TO VADER ['"', '@United', 'Right', 'now', 'at', 'Tropic', 'Air', 'in', 'San', 'Pedro']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Can you tell me Jet Airways award availability?
# INPUT TO VADER ['@united', 'Can', 'you', 'tell', 'me', 'Jet', 'Airways', 'award', 'availability', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.696, 'pos': 0.304, 'compound': 0.5423}
#
# INPUT SENTENCE NYC was awesomeee!
# INPUT TO VADER ['@JetBlue', 'love', 'traveling', 'with', 'Jetblue', '.', 'Ca', 'nt', 'wait', 'to', 'go', 'to', 'Paris', 'oui', 'oui', '!', '!', '!', 'NYC', 'was', 'awesomeee', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.749, 'pos': 0.251, 'compound': 0.7482}
#
# INPUT SENTENCE With a group and over 20 luggages are lost
# INPUT TO VADER ['@united', 'where', 'are', 'our', 'luggages', '?', 'With', 'a', 'group', 'and', 'over', '20', 'luggages', 'are', 'lost']
# VADER OUTPUT {'neg': 0.161, 'neu': 0.839, 'pos': 0.0, 'compound': -0.3182}
#
# INPUT SENTENCE I'm running iOS 8.1.3
# INPUT TO VADER ['@americanair', 'Yes', 'to', 'the', 'iOS', '.', 'I', "'m", 'running', 'iOS', '8.1.3']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.4019}
#
# INPUT SENTENCE Extremely unlikely I will make it!
# INPUT TO VADER ['@united', 'Flight', 'has', 'been', 'delayed', 'for', 'another', 'hour', 'so', 'only', 'have', '24', 'mins', 'to', 'transit', 'at', 'LAX', '...', 'Extremely', 'unlikely', 'I', 'will', 'make', 'it', '!']
# VADER OUTPUT {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'compound': -0.2942}
#
# INPUT SENTENCE @united it's disgusting and unconscionable the treatment I've received tonight.
# INPUT TO VADER ['@united', 'it', "'s", 'disgusting', 'and', 'unconscionable', 'the', 'treatment', 'I', "'ve", 'received', 'tonight', '.']
# VADER OUTPUT {'neg': 0.254, 'neu': 0.746, 'pos': 0.0, 'compound': -0.5267}
#
# INPUT SENTENCE 25 min. @ABC11_WTVD
# INPUT TO VADER ['@united', '25', 'minute', 'hold', 'is', '1', 'hr', '.', '25', 'min', '.', '@ABC11_WTVD']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Fingers Crossed!
# INPUT TO VADER ['@SouthwestAir', '#', 'DestinationDragons', 'Any', 'word', 'on', 'winners', 'of', 'contest', '?', 'Any', 'chance', 'for', 'tix', 'for', 'the', 'Provo', 'DestinationDragons', 'show', '?', 'Fingers', 'Crossed', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.747, 'pos': 0.253, 'compound': 0.6958}
#
# INPUT SENTENCE http://t.co/3zpJr7kWbk
# INPUT TO VADER ['@united', 'should', 'contact', 'me', 'and', 'the', 'others', 'on', 'my', 'flight', 'who', 'ca', "n't", 'get', 'their', 'website', 'to', 'work', '.', 'None', 'of', 'our', 'info', 'is', 'valid', '!', 'http://t.co/3zpJr7kWbk']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue will we be able to watch the Oscars on our flight tomorrow?
# INPUT TO VADER ['@JetBlue', 'will', 'we', 'be', 'able', 'to', 'watch', 'the', 'Oscars', 'on', 'our', 'flight', 'tomorrow', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Just double checking bc the site looked different.
# INPUT TO VADER ['@JetBlue', 'Received', 'an', 'invitation', 'to', 'participate', 'in', 'e', '-', 'rewards', '.', 'Is', 'this', 'legit', 'from', 'JetBlue', '?', 'Just', 'double', 'checking', 'bc', 'the', 'site', 'looked', 'different', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.866, 'pos': 0.134, 'compound': 0.4767}
#
# INPUT SENTENCE @united I want a hotel room and a whiskey.
# INPUT TO VADER ['@united', 'I', 'want', 'a', 'hotel', 'room', 'and', 'a', 'whiskey', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.0772}
#
# INPUT SENTENCE "@JetBlue Well
# INPUT TO VADER ['"', '@JetBlue', 'Well']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.323, 'pos': 0.677, 'compound': 0.2732}
#
# INPUT SENTENCE @JetBlue but Virgin has wifi 👀
# INPUT TO VADER ['@JetBlue', 'but', 'Virgin', 'has', 'wifi', '👀']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE You should be very proud :) http://t.co/oKtUkjY92O (via @ParachuteGuy)
# INPUT TO VADER ['@united', 'What', 'a', 'really', 'GREAT', '&', 'amp', ';', 'FLATTERING', 'story', 'about', 'you', '!', 'You', 'should', 'be', 'very', 'proud', ':)', 'http://t.co/oKtUkjY92O', '(', 'via', '@ParachuteGuy', ')']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'compound': 0.9467}
#
# INPUT SENTENCE I was stuck for 35 hours because of you guys
# INPUT TO VADER ['@united', 'I', 'tried', 'but', 'no', 'one', 'was', 'available', 'in', 'bogota', 'and', 'everyone', 'was', 'rude', 'in', 'Houston', '.', 'I', 'was', 'stuck', 'for', '35', 'hours', 'because', 'of', 'you', 'guys']
# VADER OUTPUT {'neg': 0.307, 'neu': 0.693, 'pos': 0.0, 'compound': -0.8519}
#
# INPUT SENTENCE @JetBlue Sent.
# INPUT TO VADER ['@JetBlue', 'Sent', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways can you help me reroute my trip?
# INPUT TO VADER ['@USAirways', 'can', 'you', 'help', 'me', 'reroute', 'my', 'trip', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.722, 'pos': 0.278, 'compound': 0.4019}
#
# INPUT SENTENCE I'd like to call them myself.
# INPUT TO VADER ['@united', 'What', 'delivery', 'service', 'do', 'you', 'use', '?', 'I', "'d", 'like', 'to', 'call', 'them', 'myself', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.3612}
#
# INPUT SENTENCE @SouthwestAir Arkansas Gov. plans to sign Governor SB-202 that legalizes discrimination of LGBT.Can you lend your voice to a state boycott?
# INPUT TO VADER ['@SouthwestAir', 'Arkansas', 'Gov.', 'plans', 'to', 'sign', 'Governor', 'SB-202', 'that', 'legalizes', 'discrimination', 'of', 'LGBT.Can', 'you', 'lend', 'your', 'voice', 'to', 'a', 'state', 'boycott', '?']
# VADER OUTPUT {'neg': 0.108, 'neu': 0.892, 'pos': 0.0, 'compound': -0.3182}
#
# INPUT SENTENCE Can this get any worse.
# INPUT TO VADER ['@united', 'OMG', '!', '!', '!', 'you', 'just', 'bumped', 'me', 'off', 'the', 'last', 'flight', '.', 'Can', 'this', 'get', 'any', 'worse', '.']
# VADER OUTPUT {'neg': 0.221, 'neu': 0.779, 'pos': 0.0, 'compound': -0.6093}
#
# INPUT SENTENCE I’ll look forward to hopefully one of those 103 on my flight home tonight :)
# INPUT TO VADER ['@JetBlue', 'credit', 'to', 'you', 'for', 'replying', '.', ' ', 'I', '’ll', 'look', 'forward', 'to', 'hopefully', 'one', 'of', 'those', '103', 'on', 'my', 'flight', 'home', 'tonight', ':)']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.684, 'pos': 0.316, 'compound': 0.8074}
#
# INPUT SENTENCE "@united hi JP
# INPUT TO VADER ['"', '@united', 'hi', 'JP']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.441, 'pos': 0.559, 'compound': 0.368}
#
# INPUT SENTENCE Thanks a lot!!
# INPUT TO VADER ['@united', 'my', 'flight', 'was', 'supposed', 'to', 'depart', 'to', 'Boston', 'at', '4:36', 'and', 'now', 'it', "'s", 'departing', 'at', '6:30', 'due', 'to', 'issues', 'with', 'finding', 'a', 'pilot', '.', 'Thanks', 'a', 'lot', '!', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.878, 'pos': 0.122, 'compound': 0.5399}
#
# INPUT SENTENCE @USAirways is a DM possible if you aren't following me?
# INPUT TO VADER ['@USAirways', 'is', 'a', 'DM', 'possible', 'if', 'you', 'are', "n't", 'following', 'me', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE To top things off
# INPUT TO VADER ['"', '@united', 'ok', '.', 'To', 'top', 'things', 'off']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.4588}
#
# INPUT SENTENCE @SouthwestAir safety back in Dallas!
# INPUT TO VADER ['@SouthwestAir', 'safety', 'back', 'in', 'Dallas', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.564, 'pos': 0.436, 'compound': 0.4753}
#
# INPUT SENTENCE @SouthwestAir I'm flying out of CUN tomorrow To DEN - can I change my flight due to the travel advisory??
# INPUT TO VADER ['@SouthwestAir', 'I', "'m", 'flying', 'out', 'of', 'CUN', 'tomorrow', 'To', 'DEN', '-', 'can', 'I', 'change', 'my', 'flight', 'due', 'to', 'the', 'travel', 'advisory', '?', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
for sentence in airline_tweets_train.data:
    lemmatized_text = sentence.decode("utf-8")
    run_vader(lemmatized_text, lemmatize=True, verbose=1)
# Out:
# INPUT SENTENCE Just wondering.
# INPUT TO VADER ['@americanair', 'why', 'be', 'your', 'cover', 'photo', 'of', 'TWA', '?', 'just', 'wonder', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united next day
# INPUT TO VADER ['@unite', 'next', 'day']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@JetBlue Thank you that it is not just a livery; it is a culture that 16
# INPUT TO VADER ['"', '@JetBlue', 'thank', 'you', 'that', 'it', 'be', 'not', 'just', 'a', 'livery', ';', 'it', 'be', 'a', 'culture', 'that', '16']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.3612}
#
# INPUT SENTENCE @SouthwestAir I cannot DM you as you do not follow me.
# INPUT TO VADER ['@southwestair', 'I', 'can', 'not', 'dm', 'you', 'as', 'you', 'do', 'not', 'follow', 'I', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@VirginAmerica Funny story
# INPUT TO VADER ['"', '@VirginAmerica', 'Funny', 'story']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.408, 'pos': 0.592, 'compound': 0.4404}
#
# INPUT SENTENCE @united flight 403 is delayed 40 min bc a missing screw and were in danger of missing flight 6491
# INPUT TO VADER ['@unite', 'flight', '403', 'be', 'delay', '40', 'min', 'bc', 'a', 'miss', 'screw', 'and', 'be', 'in', 'danger', 'of', 'miss', 'flight', '6491']
# VADER OUTPUT {'neg': 0.442, 'neu': 0.558, 'pos': 0.0, 'compound': -0.8074}
#
# INPUT SENTENCE @AmericanAir does it show that we are on the same plane?
# INPUT TO VADER ['@AmericanAir', 'do', 'it', 'show', 'that', 'we', 'be', 'on', 'the', 'same', 'plane', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Just sayin'.
# INPUT TO VADER ['@united', '@perfectomobile', 'you', 'really', 'should', 'not', 'use', 'the', 'word', "'", 'crash', '.', "'", 'just', 'sayin', "'", '.']
# VADER OUTPUT {'neg': 0.197, 'neu': 0.803, 'pos': 0.0, 'compound': -0.4019}
#
# INPUT SENTENCE @united what's a good number to call to speak with someone about how you can fix what you did to 50 people and their luggage on Saturday?
# INPUT TO VADER ['@united', 'what', 'be', 'a', 'good', 'number', 'to', 'call', 'to', 'speak', 'with', 'someone', 'about', 'how', 'you', 'can', 'fix', 'what', 'you', 'do', 'to', '50', 'people', 'and', 'their', 'luggage', 'on', 'Saturday', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.4939}
#
# INPUT SENTENCE Could Reservations help me?
# INPUT TO VADER ['@usairway', 'I', 'm', 'research', 'a', 'flight', '&', 'amp', ';', 'notice', 'a', 'small', 'issue', 'w', '/', 'class', 'of', 'service', 'between', 'your', 'site', '&', 'amp', ';', 'other', 'site', '.', 'could', 'reservation', 'help', 'I', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.4019}
#
# INPUT SENTENCE "@united never fails
# INPUT TO VADER ['"', '@united', 'never', 'fail']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.412, 'pos': 0.588, 'compound': 0.431}
#
# INPUT SENTENCE "@united hi guys
# INPUT TO VADER ['"', '@united', 'hi', 'guy']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united broken light
# INPUT TO VADER ['"', '@united', 'break', 'light']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE (2/2)
# INPUT TO VADER ['@unite', 'to', 'speak', 'to', 'a', 'real', 'person', 'to', 'get', 'this', 'resolve', 'politely', 'and', 'efficiently', '.', '(', '2/2', ')']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.678, 'pos': 0.322, 'compound': 0.6908}
#
# INPUT SENTENCE @united love the new 1st class breakfast!
# INPUT TO VADER ['@united', 'love', 'the', 'new', '1st', 'class', 'breakfast', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.572, 'pos': 0.428, 'compound': 0.6696}
#
# INPUT SENTENCE "@USAirways just heard #Monterey airport was closed due to thick fog
# INPUT TO VADER ['"', '@USAirways', 'just', 'hear', '#', 'Monterey', 'airport', 'be', 'close', 'due', 'to', 'thick', 'fog']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I have to book today.
# INPUT TO VADER ['@united', 'I', 'do', 'DM', 'the', 'detail', 'but', 'still', 'no', 'response', '.', 'I', 'have', 'to', 'book', 'today', '.']
# VADER OUTPUT {'neg': 0.189, 'neu': 0.811, 'pos': 0.0, 'compound': -0.4215}
#
# INPUT SENTENCE I'll figure out car rental changes and such.
# INPUT TO VADER ['@unite', 'yes', '1427', 'cancel', 'flightle', '.', 'move', 'to', '333', '.', 'I', 'will', 'figure', 'out', 'car', 'rental', 'change', 'and', 'such', '.']
# VADER OUTPUT {'neg': 0.107, 'neu': 0.749, 'pos': 0.144, 'compound': 0.1779}
#
# INPUT SENTENCE And yes
# INPUT TO VADER ['"', '@USAirways', 'awesome', '!', 'and', 'yes']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.22, 'pos': 0.78, 'compound': 0.7959}
#
# INPUT SENTENCE #GetMartyHome
# INPUT TO VADER ['@unite', 'it', 'be', 'UA', 'flight', '1001', '!', 'now', 'I', 'be', 'currently', 'stick', 'in', 'Portland', 'because', 'I', 'miss', 'my', 'ride', 'because', 'of', 'the', '3', 'hour', 'delay', '.', '#', 'getmartyhome']
# VADER OUTPUT {'neg': 0.173, 'neu': 0.827, 'pos': 0.0, 'compound': -0.4926}
#
# INPUT SENTENCE @SouthwestAir nice touch on the passbook integration!
# INPUT TO VADER ['@SouthwestAir', 'nice', 'touch', 'on', 'the', 'passbook', 'integration', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.66, 'pos': 0.34, 'compound': 0.4753}
#
# INPUT SENTENCE Keep it up :) @AmericanAir
# INPUT TO VADER ['keep', 'it', 'up', ':)', '@AmericanAir']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.571, 'pos': 0.429, 'compound': 0.4588}
#
# INPUT SENTENCE thank you so much!!
# INPUT TO VADER ['@americanair', 'do', '!', '!', 'thank', 'you', 'so', 'much', '!', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'compound': 0.5673}
#
# INPUT SENTENCE @USAirways any chance of a travel advisory or DCA this weekend?
# INPUT TO VADER ['@usairway', 'any', 'chance', 'of', 'a', 'travel', 'advisory', 'or', 'DCA', 'this', 'weekend', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.818, 'pos': 0.182, 'compound': 0.25}
#
# INPUT SENTENCE But great agents in savannah!
# INPUT TO VADER ['@jetblue', 'keep', 'go', 'back', 'and', 'forth', 'with', 'be', 'able', 'to', 'board', 'and', 'then', 'not', '.', 'but', 'great', 'agent', 'in', 'savannah', '!']
# VADER OUTPUT {'neg': 0.208, 'neu': 0.792, 'pos': 0.0, 'compound': -0.694}
#
# INPUT SENTENCE "@JetBlue Flight 152 (N559JB) ""Here's Looking at Blue Kid"" departs @MCO enroute to @BostonLogan http://t.co/qeaDA92MW6"
# INPUT TO VADER ['"', '@JetBlue', 'Flight', '152', '(', 'N559JB', ')', '"', '"', 'here', 'be', 'look', 'at', 'Blue', 'Kid', '"', '"', 'depart', '@mco', 'enroute', 'to', '@bostonlogan', 'http://t.co/qeada92mw6', '"']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united diverged to Burlington
# INPUT TO VADER ['"', '@united', 'diverge', 'to', 'Burlington']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united thank you for taking care of my mom and reFlight Booking Problems her flight in phl.
# INPUT TO VADER ['@united', 'thank', 'you', 'for', 'take', 'care', 'of', 'my', 'mom', 'and', 'reflight', 'Booking', 'problem', 'her', 'flight', 'in', 'phl', '.']
# VADER OUTPUT {'neg': 0.121, 'neu': 0.625, 'pos': 0.254, 'compound': 0.4588}
#
# INPUT SENTENCE @united thanks we'll be in touch!
# INPUT TO VADER ['@unite', 'thank', 'we', 'will', 'be', 'in', 'touch', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.4199}
#
# INPUT SENTENCE @united line full of worried customers and guy at desk says so sorry you will have to take care of your problems Late Flightr I don't have time.
# INPUT TO VADER ['@united', 'line', 'full', 'of', 'worried', 'customer', 'and', 'guy', 'at', 'desk', 'say', 'so', 'sorry', 'you', 'will', 'have', 'to', 'take', 'care', 'of', 'your', 'problem', 'Late', 'Flightr', 'I', 'do', 'not', 'have', 'time', '.']
# VADER OUTPUT {'neg': 0.196, 'neu': 0.709, 'pos': 0.095, 'compound': -0.3488}
#
# INPUT SENTENCE @united my flight is Late Flight due to mechanical issues 3 of 4 flights in past 10 days!
# INPUT TO VADER ['@united', 'my', 'flight', 'be', 'Late', 'Flight', 'due', 'to', 'mechanical', 'issue', '3', 'of', '4', 'flight', 'in', 'past', '10', 'day', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united please arrange someone at the arriving gate of flight 5957 to Chicago for either a refund or first class upgrade
# INPUT TO VADER ['@unite', 'please', 'arrange', 'someone', 'at', 'the', 'arrive', 'gate', 'of', 'flight', '5957', 'to', 'Chicago', 'for', 'either', 'a', 'refund', 'or', 'first', 'class', 'upgrade']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.892, 'pos': 0.108, 'compound': 0.3182}
#
# INPUT SENTENCE each united employee
# INPUT TO VADER ['"', '@unite', 'not', 'appropriate', 'to', 'ask', 'in', 'public', '(', 'hence', 'the', 'dm', ')', '.', 'each', 'united', 'employee']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.811, 'pos': 0.189, 'compound': 0.4215}
#
# INPUT SENTENCE On a good note
# INPUT TO VADER ['"', '@USAirways', 'thank', 'for', 'the', 'reply', '.', 'on', 'a', 'good', 'note']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.6597}
#
# INPUT SENTENCE http://t.co/dN1if2cGwE
# INPUT TO VADER ['@United', 'be', 'freak', 'worthless', '.', 'I', 'hate', 'this', 'airline', '.', 'http://t.co/dN1if2cGwE']
# VADER OUTPUT {'neg': 0.655, 'neu': 0.345, 'pos': 0.0, 'compound': -0.8591}
#
# INPUT SENTENCE "@united if you're going to Cancelled Flight flights today
# INPUT TO VADER ['"', '@united', 'if', 'you', 'be', 'go', 'to', 'cancel', 'flight', 'flight', 'today']
# VADER OUTPUT {'neg': 0.182, 'neu': 0.818, 'pos': 0.0, 'compound': -0.25}
#
# INPUT SENTENCE @AmericanAir drop me a follow I need help
# INPUT TO VADER ['@americanair', 'drop', 'I', 'a', 'follow', 'I', 'need', 'help']
# VADER OUTPUT {'neg': 0.269, 'neu': 0.385, 'pos': 0.346, 'compound': 0.1531}
#
# INPUT SENTENCE http://t.co/mpi4yuo9jR” Oh word!!!!??????
# INPUT TO VADER ['"', '@jetblue', ':', 'our', 'fleet', 'be', 'on', 'fleek', '.', 'http://t.co/mpi4yuo9jR', '"', 'oh', 'word', '!', '!', '!', '!', '?', '?', '?', '?', '?', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@VirginAmerica has getaway deals through May
# INPUT TO VADER ['"', '@VirginAmerica', 'have', 'getaway', 'deal', 'through', 'May']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir iPhone App Adds Passbook Support #Airlines #Travel http://t.co/lJzDTHD9Bv
# INPUT TO VADER ['@SouthwestAir', 'iPhone', 'App', 'add', 'Passbook', 'Support', '#', 'Airlines', '#', 'Travel', 'http://t.co/ljzdthd9bv']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.4019}
#
# INPUT SENTENCE Just a second.
# INPUT TO VADER ['@SouthwestAir', 'sure', 'can', '!', 'just', 'a', 'second', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.607, 'pos': 0.393, 'compound': 0.3802}
#
# INPUT SENTENCE Send Bloody Mary's to row 27!!!
# INPUT TO VADER ['@USAirways', 'make', 'it', '!', '!', '!', 'send', 'Bloody', 'Mary', "'s", 'to', 'row', '27', '!', '!', '!']
# VADER OUTPUT {'neg': 0.311, 'neu': 0.689, 'pos': 0.0, 'compound': -0.6209}
#
# INPUT SENTENCE Pretty ridiculous.
# INPUT TO VADER ['@united', 'connection', 'at', 'ORD', 'be', 'on', 'the', 'exact', 'same', 'plane', 'again', '.', 'check', 'carry', '-', 'on', 'be', 'apparently', 'take', 'off', '&', 'amp', ';', 'leave', 'in', 'Chicago', '.', 'pretty', 'ridiculous', '.']
# VADER OUTPUT {'neg': 0.133, 'neu': 0.753, 'pos': 0.115, 'compound': 0.128}
#
# INPUT SENTENCE Good #customerservice is dead."
# INPUT TO VADER ['"', '@united', 'cancel', 'Flights', 'flt', 'from', 'EWR', '.', '"', '"', 'no', 'crew""', '.', 'tell', 'wife', '&', 'amp', ';', '4', 'yr', 'old', 'to', '"', '"', 'get', 'to', 'NY', 'to', 'catch', '@AirCanada', '"', '"', 'to', 'YYZ', '!', 'good', '#', 'customerservice', 'be', 'dead', '.', '"']
# VADER OUTPUT {'neg': 0.261, 'neu': 0.653, 'pos': 0.086, 'compound': -0.7088}
#
# INPUT SENTENCE "@VirginAmerica I rang
# INPUT TO VADER ['"', '@VirginAmerica', 'I', 'ring']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Can we combine res?
# INPUT TO VADER ['@united', 'assume', 'those', 'benefit', 'only', 'apply', 'to', 'my', 'own', 'reservation', '.', 'any', 'way', 'my', 'partner', '(', 'on', 'diff', 'res', ')', 'can', 'use', 'they', '?', 'can', 'we', 'combine', 're', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.873, 'pos': 0.127, 'compound': 0.5204}
#
# INPUT SENTENCE I am being told that I am asking for a refund on a used ticket on a flight that got Cancelled Flightled how is the ticket used?
# INPUT TO VADER ['@united', 'contd', '...', 'I', 'be', 'be', 'tell', 'that', 'I', 'be', 'ask', 'for', 'a', 'refund', 'on', 'a', 'use', 'ticket', 'on', 'a', 'flight', 'that', 'get', 'cancel', 'flightle', 'how', 'be', 'the', 'ticket', 'use', '?']
# VADER OUTPUT {'neg': 0.077, 'neu': 0.923, 'pos': 0.0, 'compound': -0.25}
#
# INPUT SENTENCE Never ever flying United again #joke
# INPUT TO VADER ['@united', 'you', 'have', 'now', 'lose', 'my', 'bag', '.', 'never', 'ever', 'fly', 'United', 'again', '#', 'joke']
# VADER OUTPUT {'neg': 0.292, 'neu': 0.58, 'pos': 0.128, 'compound': -0.4276}
#
# INPUT SENTENCE @united if I was rebooked do I have to pick up my luggage?
# INPUT TO VADER ['@unite', 'if', 'I', 'be', 'rebooke', 'do', 'I', 'have', 'to', 'pick', 'up', 'my', 'luggage', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Super professional!
# INPUT TO VADER ['@USAirways', 'Best', 'GAgent', 'in', 'a', 'long', 'time', '-', 'Danny', 'B.', 'for', 'US628', 'DFW', '-', 'CLT', '.', 'appreciate', 'how', 'up', 'to', 'date', 'he', 'keep', 'we', 'during', 'irrop', '.', 'super', 'professional', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.654, 'pos': 0.346, 'compound': 0.902}
#
# INPUT SENTENCE Or at least prepared with a gate when we land!
# INPUT TO VADER ['@unite', 'too', 'big', 'to', 'properly', 'manage', 'flight', 'time', '.', 'there', 'be', 'such', 'a', 'thing', 'as', 'be', 'on', 'time', '.', 'or', 'at', 'least', 'prepare', 'with', 'a', 'gate', 'when', 'we', 'land', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE And to @PamGrout for positive thoughts.
# INPUT TO VADER ['@jetblue', 'thank', 'you', 'for', 'the', 'service', 'credit', '.', 'and', 'to', '@pamgrout', 'for', 'positive', 'thought', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.535, 'pos': 0.465, 'compound': 0.8271}
#
# INPUT SENTENCE "@united Late Flight 2014 and 2015 are huge step towards decline in service
# INPUT TO VADER ['"', '@united', 'late', 'Flight', '2014', 'and', '2015', 'be', 'huge', 'step', 'towards', 'decline', 'in', 'service']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.3182}
#
# INPUT SENTENCE Denver to LAX and it's wonderful!!!
# INPUT TO VADER ['@unite', 'I', 'think', 'this', 'be', 'the', 'good', 'first', 'class', 'I', 'have', 'ever', 'get', '!', '!', ' ', 'Denver', 'to', 'LAX', 'and', 'it', 'be', 'wonderful', '!', '!', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.673, 'pos': 0.327, 'compound': 0.8302}
#
# INPUT SENTENCE "@VirginAmerica I spoke with a representative that offered no solution
# INPUT TO VADER ['"', '@VirginAmerica', 'I', 'speak', 'with', 'a', 'representative', 'that', 'offer', 'no', 'solution']
# VADER OUTPUT {'neg': 0.21, 'neu': 0.571, 'pos': 0.219, 'compound': 0.0258}
#
# INPUT SENTENCE Can I DM you the info?
# INPUT TO VADER ['@united', 'ok', '.', 'can', 'I', 'DM', 'you', 'the', 'info', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'compound': 0.296}
#
# INPUT SENTENCE @united if I miss the #Oscars I'll never fly united again
# INPUT TO VADER ['@unite', 'if', 'I', 'miss', 'the', '#', 'Oscars', 'I', 'will', 'never', 'fly', 'unite', 'again']
# VADER OUTPUT {'neg': 0.151, 'neu': 0.849, 'pos': 0.0, 'compound': -0.1531}
#
# INPUT SENTENCE @JetBlue is definitely my new favorite airline.
# INPUT TO VADER ['@jetblue', 'be', 'definitely', 'my', 'new', 'favorite', 'airline', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.467, 'pos': 0.533, 'compound': 0.6908}
#
# INPUT SENTENCE Thanks!
# INPUT TO VADER ['@USAirways', 'look', 'like', 'our', 'bag', 'have', 'be', 'rescue', '.', 'thank', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.411, 'pos': 0.589, 'compound': 0.8221}
#
# INPUT SENTENCE All good now.
# INPUT TO VADER ['@united', 'be', 'able', 'to', 'send', 'the', 'DM', '.', 'all', 'good', 'now', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.4404}
#
# INPUT SENTENCE united has no baby meals
# INPUT TO VADER ['@united', 'force', 'we', 'to', 'check', 'our', 'baby', 'bag', 'on', 'overbooked', 'flight', 'complain', 'to', 'wife', 'that', 'we', 'need', 'to', 'much', 'for', 'our', 'baby', '..', 'united', 'have', 'no', 'baby', 'meal']
# VADER OUTPUT {'neg': 0.145, 'neu': 0.769, 'pos': 0.086, 'compound': -0.2263}
#
# INPUT SENTENCE @AmericanAir OK I will call them likely tmrw UK time to question the process getting the change charge reversed due to a bereavement
# INPUT TO VADER ['@americanair', 'ok', 'I', 'will', 'call', 'they', 'likely', 'tmrw', 'UK', 'time', 'to', 'question', 'the', 'process', 'get', 'the', 'change', 'charge', 'reverse', 'due', 'to', 'a', 'bereavement']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.901, 'pos': 0.099, 'compound': 0.296}
#
# INPUT SENTENCE You made the difficult weather days proficient and enjoyable.
# INPUT TO VADER ['@united', 'thank', 'you', 'for', 'the', 'new', 'Club', 'at', "O'Hare", '.', 'very', 'comfortable', '.', 'you', 'make', 'the', 'difficult', 'weather', 'day', 'proficient', 'and', 'enjoyable', '.']
# VADER OUTPUT {'neg': 0.091, 'neu': 0.582, 'pos': 0.327, 'compound': 0.7574}
#
# INPUT SENTENCE Mind if I ask
# INPUT TO VADER ['"', '@americanair', 'thank', 'gang', '!', 'mind', 'if', 'I', 'ask']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.642, 'pos': 0.358, 'compound': 0.4199}
#
# INPUT SENTENCE Thanks!
# INPUT TO VADER ['@usairway', 'FYI', 'your', 'customer', 'service', 'rep', 'Carol', 'be', 'an', 'absolute', 'delight', '.', 'so', 'pleasant', 'to', 'with', 'with', 'and', 'rebooke', 'I', 'in', 'lightning', 'speed', '!', 'thank', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.567, 'pos': 0.433, 'compound': 0.9295}
#
# INPUT SENTENCE ^EY”
# INPUT TO VADER ['yes', '!', '!', 'thank', 'so', 'much', '!', '!', '!', '💜', '"', '@unite', ':', '@whitterbug', 'we', 'see', 'you', 'speak', 'with', 'our', 'Reservations', 'team', 'and', 'they', 'have', 'reinstate', 'the', 'flight', '.', 'thank', '.', '^EY', '"']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.8346}
#
# INPUT SENTENCE http://t.co/2nY5TuXFqf
# INPUT TO VADER ['@united', 'why', 'do', 'I', 'have', 'to', 'give', 'up', 'my', 'leg', 'room', 'so', 'these', '4', 'people', '(', 'not', 'in', 'my', 'row', ')', 'can', 'fill', 'the', 'bin', '?', ' ', 'pls', 'start', 'charge', '.', 'http://t.co/2nY5TuXFqf']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.949, 'pos': 0.051, 'compound': 0.0772}
#
# INPUT SENTENCE and how does one obtain this companion pass?
# INPUT TO VADER ['@southwestair', '...', 'and', 'how', 'do', 'one', 'obtain', 'this', 'companion', 'pass', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united SATURDAY this morning Man dies from Ebola http://t.co/hXVVIS0VWw
# INPUT TO VADER ['@united', 'SATURDAY', 'this', 'morning', 'Man', 'die', 'from', 'Ebola', 'http://t.co/hXVVIS0VWw']
# VADER OUTPUT {'neg': 0.328, 'neu': 0.672, 'pos': 0.0, 'compound': -0.5994}
#
# INPUT SENTENCE "Thank you
# INPUT TO VADER ['"', 'thank', 'you']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'compound': 0.3612}
#
# INPUT SENTENCE "@JetBlue can your people working this contact me
# INPUT TO VADER ['"', '@jetblue', 'can', 'your', 'people', 'work', 'this', 'contact', 'I']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Or we could just delay :/
# INPUT TO VADER ['@unite', 'why', 'do', 'not', 'you', 'de', '-', 'ice', 'while', 'the', 'plane', 'sit', 'there', 'with', 'no', 'one', 'in', 'it', 'for', '2', 'hour', '?', '?', 'or', 'we', 'could', 'just', 'delay', ':/']
# VADER OUTPUT {'neg': 0.248, 'neu': 0.752, 'pos': 0.0, 'compound': -0.7399}
#
# INPUT SENTENCE #UnitedAirlines
# INPUT TO VADER ['.@united', 'let', 'we', 'know', 'when', 'you', 'find', 'everyone', "'s", 'luggage', '.', 'thank', '.', '#', 'UnitedAirlines']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.815, 'pos': 0.185, 'compound': 0.3612}
#
# INPUT SENTENCE "@united so going forward
# INPUT TO VADER ['"', '@united', 'so', 'go', 'forward']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE sent
# INPUT TO VADER ['"', '@USAirways', ':', '@AnnetteNaif', 'we', 'appreciate', 'the', '#', 'shoutout', 'for', 'Roberto', '.', 'DM', 'your', 'confirmation', 'code', 'so', 'we', 'can', 'forward', 'your', 'kind', 'word', '.', '"', 'send']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.747, 'pos': 0.253, 'compound': 0.7269}
#
# INPUT SENTENCE http://t.co/dSDEbodmEL
# INPUT TO VADER ['👉', '🚪', 'RT', '@jetblue', ':', 'our', 'fleet', 'be', 'on', 'fleek', '.', 'http://t.co/dSDEbodmEL']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE http://t.co/bNgpli8JT6
# INPUT TO VADER ['@united', 'have', 'you', 'inspect', 'the', 'picture', '?', 'routine', 'aircraft', 'check', 'while', 'on', 'his', 'cell', 'phone', '?', 'what', 'will', 'the', 'FAA', '&', 'amp', ';', 'NYT', 'say', '?', 'http://t.co/bNgpli8JT6']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united this is atrocious customer service.
# INPUT TO VADER ['@united', 'this', 'be', 'atrocious', 'customer', 'service', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@AmericanAir sure
# INPUT TO VADER ['"', '@americanair', 'sure']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'compound': 0.3182}
#
# INPUT SENTENCE I have to be refunded whenever I get at my final destination or not!
# INPUT TO VADER ['@unite', 'ridiculous', '!', 'I', 'have', 'to', 'be', 'refund', 'whenever', 'I', 'get', 'at', 'my', 'final', 'destination', 'or', 'not', '!']
# VADER OUTPUT {'neg': 0.192, 'neu': 0.808, 'pos': 0.0, 'compound': -0.4738}
#
# INPUT SENTENCE "@SouthwestAir oops
# INPUT TO VADER ['"', '@southwestair', 'oops']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Why do I have to play for hotel tonight in #ewr?
# INPUT TO VADER ['@united', 'late', 'Flight', 'crew', 'into', '#', 'btv', 'last', 'nite', 'delay', 'today', 'flt', '.', 'will', 'miss', 'connection', 'to', '#', 'cun', '.', 'why', 'do', 'I', 'have', 'to', 'play', 'for', 'hotel', 'tonight', 'in', '#', 'ewr', '?']
# VADER OUTPUT {'neg': 0.133, 'neu': 0.785, 'pos': 0.082, 'compound': -0.128}
#
# INPUT SENTENCE "@AmericanAir I have a couple questions for you
# INPUT TO VADER ['"', '@americanair', 'I', 'have', 'a', 'couple', 'question', 'for', 'you']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "Nice RT @VirginAmerica: The man of steel might be faster
# INPUT TO VADER ['"', 'Nice', 'RT', '@VirginAmerica', ':', 'the', 'man', 'of', 'steel', 'might', 'be', 'fast']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.4215}
#
# INPUT SENTENCE @SouthwestAir how are flights looking for tomorrow morning from #Nashville (BNA) to Fort Lauderdale (FLL) ?!
# INPUT TO VADER ['@southwestair', 'how', 'be', 'flight', 'look', 'for', 'tomorrow', 'morning', 'from', '#', 'Nashville', '(', 'BNA', ')', 'to', 'Fort', 'Lauderdale', '(', 'FLL', ')', '?', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE this experience just keeps getting worse and worse
# INPUT TO VADER ['@united', 'now', 'be', 'on', 'board', 'with', 'no', 'movement', 'for', '25', 'min', '...', 'wow', 'this', 'experience', 'just', 'keep', 'get', 'bad', 'and', 'bad']
# VADER OUTPUT {'neg': 0.307, 'neu': 0.567, 'pos': 0.127, 'compound': -0.6597}
#
# INPUT SENTENCE Great people at your call center!
# INPUT TO VADER ['@USAirways', ' ', 'thank', 'you', '!', 'glad', 'to', 'be', 'head', 'home', '!', 'great', 'people', 'at', 'your', 'call', 'center', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.512, 'pos': 0.488, 'compound': 0.8879}
#
# INPUT SENTENCE Im so Flight Booking Problems my next flight with you!
# INPUT TO VADER ['@jetblue', 'here', 'in', 'Austin', 'I', 'see', 'the', 'water', 'bottle', '&', 'amp', ';', 'snack', '@', 'the', 'desk', 'for', 'your', 'waiting', 'passenger', '!', 'I', 'm', 'so', 'Flight', 'Booking', 'problem', 'my', 'next', 'flight', 'with', 'you', '!']
# VADER OUTPUT {'neg': 0.129, 'neu': 0.871, 'pos': 0.0, 'compound': -0.5496}
#
# INPUT SENTENCE "@united your first class is a joke
# INPUT TO VADER ['"', '@unite', 'your', 'first', 'class', 'be', 'a', 'joke']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.694, 'pos': 0.306, 'compound': 0.296}
#
# INPUT SENTENCE Hope to be flying with you guys soon!
# INPUT TO VADER ['@jetblue', 'okay', 'thank', '.', 'hope', 'to', 'be', 'fly', 'with', 'you', 'guy', 'soon', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.513, 'pos': 0.487, 'compound': 0.7644}
#
# INPUT SENTENCE "@united enough already with the poor service
# INPUT TO VADER ['"', '@unite', 'enough', 'already', 'with', 'the', 'poor', 'service']
# VADER OUTPUT {'neg': 0.341, 'neu': 0.659, 'pos': 0.0, 'compound': -0.4767}
#
# INPUT SENTENCE @united I wasn't asking for a full refund but delaying me 3 hours and giving no reason should be enough to give partial credit
# INPUT TO VADER ['@united', 'I', 'be', 'not', 'ask', 'for', 'a', 'full', 'refund', 'but', 'delay', 'I', '3', 'hour', 'and', 'give', 'no', 'reason', 'should', 'be', 'enough', 'to', 'give', 'partial', 'credit']
# VADER OUTPUT {'neg': 0.212, 'neu': 0.663, 'pos': 0.125, 'compound': -0.3291}
#
# INPUT SENTENCE @JetBlue thank you!!
# INPUT TO VADER ['@jetblue', 'thank', 'you', '!', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.393, 'pos': 0.607, 'compound': 0.4738}
#
# INPUT SENTENCE Thank you!!
# INPUT TO VADER ['@unite', 'your', 'agent', '(', 'and', 'service', ')', 'on', 'my', 'weekend', 'trip', 'have', 'be', 'amazing', '!', '!', '!', 'thank', 'you', '!', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.616, 'pos': 0.384, 'compound': 0.816}
#
# INPUT SENTENCE As of yet
# INPUT TO VADER ['"', '@unite', 'well', '.', 'as', 'of', 'yet']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.2732}
#
# INPUT SENTENCE Thank you.
# INPUT TO VADER ['@United', 'Claudia', 'in', 'IAH', 'terminal', 'b', 'travel', 'assistance', 'have', 'I', 'all', 'set', '.', 'great', 'service', '.', 'thank', 'you', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'compound': 0.765}
#
# INPUT SENTENCE @united another awesome new plane flight 1584 and extremely nice Captain Steve Connolly.
# INPUT TO VADER ['@unite', 'another', 'awesome', 'new', 'plane', 'flight', '1584', 'and', 'extremely', 'nice', 'Captain', 'Steve', 'Connolly', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.605, 'pos': 0.395, 'compound': 0.8016}
#
# INPUT SENTENCE NEVER AGAIN with @united
# INPUT TO VADER ['@united', 'WTF', '!', '?', '!', '?', 'Delay', 'after', 'delay', '.', '15', 'hour', 'YVR', 'to', 'SAN', '?', 'Unacceptable', '.', 'Flight', 'Crew', 'Availability', 'be', 'to', 'blame', '?', 'never', 'again', 'with', '@united']
# VADER OUTPUT {'neg': 0.501, 'neu': 0.499, 'pos': 0.0, 'compound': -0.944}
#
# INPUT SENTENCE @SouthwestAir yes please
# INPUT TO VADER ['@southwestair', 'yes', 'please']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.167, 'pos': 0.833, 'compound': 0.6124}
#
# INPUT SENTENCE "@united I was insulted
# INPUT TO VADER ['"', '@united', 'I', 'be', 'insult']
# VADER OUTPUT {'neg': 0.623, 'neu': 0.377, 'pos': 0.0, 'compound': -0.5106}
#
# INPUT SENTENCE @virginamerica may start service to Hawaii from #SanFrancisco this year http://t.co/yPo7nYpRZl #biztravel
# INPUT TO VADER ['@virginamerica', 'may', 'start', 'service', 'to', 'Hawaii', 'from', '#', 'SanFrancisco', 'this', 'year', 'http://t.co/ypo7nyprzl', '#', 'biztravel']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united @czamkoff It's all about profit
# INPUT TO VADER ['"', '@united', '@czamkoff', 'it', 'be', 'all', 'about', 'profit']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.4404}
#
# INPUT SENTENCE Left us in the cold in DEN.
# INPUT TO VADER ['@united', '#', 'UnitedAirlines', 'pl', 'fix', '#', 'AspenBaggageFail', 'issue', '.', 'have', 'to', 'pay', 'my', 'own', 'way', 'to', '#', 'Aspen', 'after', 'flight', 'cancel', 'Flight', '.', 'leave', 'we', 'in', 'the', 'cold', 'in', 'DEN', '.']
# VADER OUTPUT {'neg': 0.173, 'neu': 0.827, 'pos': 0.0, 'compound': -0.3818}
#
# INPUT SENTENCE #ua1523
# INPUT TO VADER ['@unite', 'bad', 'idea', 'to', 'let', '200', 'people', 'back', 'on', 'the', 'terminal', 'with', 'food', 'voucher', 'but', 'allow', 'only', '15', 'minute', 'to', 'get', 'anything', '.', ' ', 'long', 'line', '!', '!', '#', 'ua1523']
# VADER OUTPUT {'neg': 0.08, 'neu': 0.816, 'pos': 0.104, 'compound': 0.1739}
#
# INPUT SENTENCE "@united what
# INPUT TO VADER ['"', '@unite', 'what']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE contact http://t.co/aQjn4HwNaC  we negotiate resolutions for You!
# INPUT TO VADER ['@JetBlue', 'Airline', 'trouble', 'this', 'winter', '&', 'amp', ';', 'not', 'get', 'good', 'customer', 'service', '?', 'contact', 'http://t.co/aQjn4HwNaC', ' ', 'we', 'negotiate', 'resolution', 'for', 'you', '!']
# VADER OUTPUT {'neg': 0.252, 'neu': 0.748, 'pos': 0.0, 'compound': -0.6595}
#
# INPUT SENTENCE @AmericanAir @dfwairport you 2 together are the best part of flying!
# INPUT TO VADER ['@AmericanAir', '@dfwairport', 'you', '2', 'together', 'be', 'the', 'good', 'part', 'of', 'fly', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.4926}
#
# INPUT SENTENCE #veryimportantproject
# INPUT TO VADER ['@americanair', '@cityandsand', 'we', 'be', 'try', 'to', 'coordinate', 'an', 'airport', 'hand', '-', 'off', 'of', 'Nutella', '!', '#', 'veryimportantproject']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.788, 'pos': 0.212, 'compound': 0.5411}
#
# INPUT SENTENCE http://t.co/aypyaDUY6a
# INPUT TO VADER ['@southwestair', 'never', 'feel', 'well', 'take', 'care', 'of', '!', 'indian', 'auntie', 'be', 'the', 'gold', 'standard', '.', 'thank', 'Aruna', '!', 'http://t.co/aypyaDUY6a']
# VADER OUTPUT {'neg': 0.086, 'neu': 0.616, 'pos': 0.298, 'compound': 0.6673}
#
# INPUT SENTENCE Although the wait was long due to weather r/scheduling
# INPUT TO VADER ['"', '@southwestair', 'although', 'the', 'wait', 'be', 'long', 'due', 'to', 'weather', 'r', '/', 'scheduling']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Pleased to be a Premier Platinum
# INPUT TO VADER ['@united', 'Pleased', 'to', 'be', 'a', 'Premier', 'Platinum']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'compound': 0.4404}
#
# INPUT SENTENCE @AmericanAir is that the flight for tomorrow?
# INPUT TO VADER ['@AmericanAir', 'be', 'that', 'the', 'flight', 'for', 'tomorrow', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Another awful experience and Victoria at the check in desk in STL could not have been more rude and condescending.
# INPUT TO VADER ['@united', 'another', 'awful', 'experience', 'and', 'Victoria', 'at', 'the', 'check', 'in', 'desk', 'in', 'STL', 'could', 'not', 'have', 'be', 'more', 'rude', 'and', 'condescend', '.']
# VADER OUTPUT {'neg': 0.249, 'neu': 0.751, 'pos': 0.0, 'compound': -0.7425}
#
# INPUT SENTENCE @united thanks
# INPUT TO VADER ['@unite', 'thank']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'compound': 0.3612}
#
# INPUT SENTENCE Thank you for providing one bright spot in a frustrating situation.
# INPUT TO VADER ['@SouthwestAir', 'Karen', 'with', 'customer', 'service', 'be', 'very', 'helpful', '.', 'thank', 'you', 'for', 'provide', 'one', 'bright', 'spot', 'in', 'a', 'frustrating', 'situation', '.']
# VADER OUTPUT {'neg': 0.113, 'neu': 0.545, 'pos': 0.342, 'compound': 0.707}
#
# INPUT SENTENCE "@united boarding was decent
# INPUT TO VADER ['"', '@united', 'boarding', 'be', 'decent']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE keep your paper work ready and don't delay our flights(#1585)and meetings @ChooseChicago
# INPUT TO VADER ['@unite', 'common', '!', '!', 'keep', 'your', 'paper', 'work', 'ready', 'and', 'do', 'not', 'delay', 'our', 'flights(#1585)and', 'meeting', '@ChooseChicago']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.72, 'pos': 0.28, 'compound': 0.6182}
#
# INPUT SENTENCE I appreciate you working with me
# INPUT TO VADER ['@united', 'thank', 'you', 'for', 'listen', 'to', 'my', 'compliant', 'and', 'do', 'the', 'right', 'thing', '.', 'I', 'appreciate', 'you', 'work', 'with', 'I']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.743, 'pos': 0.257, 'compound': 0.6369}
#
# INPUT SENTENCE Unacceptable
# INPUT TO VADER ['@unite', 'so', 'disgusted', 'and', 'disappoint', 'with', 'united', 'airlines', 'luggage', 'policy', 'and', 'attitude', 'toward', 'musician', '.', 'unacceptable']
# VADER OUTPUT {'neg': 0.412, 'neu': 0.469, 'pos': 0.119, 'compound': -0.7818}
#
# INPUT SENTENCE Not waste their time?!
# INPUT TO VADER ['@unite', 'thank', 'KP', '.', ' ', 'what', 'be', 'go', 'on', 'w/4840', 'tonight', '.', ' ', 'bad', 'update', 'online', 'and', 'phone', '.', 'can', 'not', 'u', 'give', 'customer', 'good', 'info', '.', 'not', 'waste', 'their', 'time', '?', '!']
# VADER OUTPUT {'neg': 0.2, 'neu': 0.645, 'pos': 0.156, 'compound': -0.3326}
#
# INPUT SENTENCE @AmericanAir followback
# INPUT TO VADER ['@AmericanAir', 'followback']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@VirginAmerica Anytime
# INPUT TO VADER ['"', '@VirginAmerica', 'anytime']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways in a few weeks
# INPUT TO VADER ['@usairway', 'in', 'a', 'few', 'week']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue Seems very likely.
# INPUT TO VADER ['@jetblue', 'seem', 'very', 'likely', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @AmericanAir can I send you my trusted traveler ID to add to my reservation for tsa pre?
# INPUT TO VADER ['@AmericanAir', 'can', 'I', 'send', 'you', 'my', 'trust', 'traveler', 'ID', 'to', 'add', 'to', 'my', 'reservation', 'for', 'tsa', 'pre', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.5106}
#
# INPUT SENTENCE Was told ""we can't find a supervisor."""
# INPUT TO VADER ['"', '@unite', 'once', 'he', 'find', 'out', 'we', 'have', 'a', 'problem', 'he', 'avoid', 'I', 'like', 'the', 'plague', '.', 'be', 'tell', '"', '"', 'we', 'can', 'not', 'find', 'a', 'supervisor', '.', '"', '"', '"']
# VADER OUTPUT {'neg': 0.201, 'neu': 0.697, 'pos': 0.102, 'compound': -0.34}
#
# INPUT SENTENCE NEVER AGAIN!
# INPUT TO VADER ['@unite', 'screw', 'up', 'again', '...', 'to', 'be', 'expect', '!', 'never', 'again', '!']
# VADER OUTPUT {'neg': 0.181, 'neu': 0.819, 'pos': 0.0, 'compound': -0.2462}
#
# INPUT SENTENCE @VirginAmerica your beautiful front-end design is down right now; but it was cool to still book my ticket b/c all your back-end was secure.
# INPUT TO VADER ['@VirginAmerica', 'your', 'beautiful', 'front', '-', 'end', 'design', 'be', 'down', 'right', 'now', ';', 'but', 'it', 'be', 'cool', 'to', 'still', 'book', 'my', 'ticket', 'b', '/', 'c', 'all', 'your', 'back', '-', 'end', 'be', 'secure', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.721, 'pos': 0.279, 'compound': 0.8176}
#
# INPUT SENTENCE r lying how can I help
# INPUT TO VADER ['@unite', 'the', 'refund', 'team', 'be', 'far', 'from', 'customer', 'care', 'courtesy', 'they', 'need', 'training', 'on', 'work', 'ethic', '.', 'so', 'it', 'be', 'like', 'sir', 'u', 'r', 'lie', 'how', 'can', 'I', 'help']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.653, 'pos': 0.347, 'compound': 0.8797}
#
# INPUT SENTENCE "@JetBlue's CEO #pilots among ardent fans
# INPUT TO VADER ['"', '@JetBlue', "'s", 'ceo', '#', 'pilot', 'among', 'ardent', 'fan']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.481, 'pos': 0.519, 'compound': 0.6597}
#
# INPUT SENTENCE @SouthwestAir can you help
# INPUT TO VADER ['@SouthwestAir', 'can', 'you', 'help']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.4019}
#
# INPUT SENTENCE @united they did on a delta flight out of LAX which is why I should be compensated for my rental car there.
# INPUT TO VADER ['@united', 'they', 'do', 'on', 'a', 'delta', 'flight', 'out', 'of', 'LAX', 'which', 'be', 'why', 'I', 'should', 'be', 'compensate', 'for', 'my', 'rental', 'car', 'there', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir https://t.co/OQUKSo3s2O subscribe please https://t.co/OQUKSo3s2O
# INPUT TO VADER ['@SouthwestAir', 'https://t.co/OQUKSo3s2O', 'subscribe', 'please', 'https://t.co/OQUKSo3s2O']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.635, 'pos': 0.365, 'compound': 0.3182}
#
# INPUT SENTENCE @united look at this beauty 😉 dc 10 united airlines 😉 http://t.co/MvYoizRPdE
# INPUT TO VADER ['@united', 'look', 'at', 'this', 'beauty', '😉', 'dc', '10', 'united', 'airlines', '😉', 'http://t.co/MvYoizRPdE']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.523, 'pos': 0.477, 'compound': 0.8074}
#
# INPUT SENTENCE "@JetBlue quick question
# INPUT TO VADER ['"', '@jetblue', 'quick', 'question']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@VirginAmerica can't check in
# INPUT TO VADER ['"', '@VirginAmerica', 'can', 'not', 'check', 'in']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united After an hour+ wait
# INPUT TO VADER ['"', '@unite', 'after', 'an', 'hour+', 'wait']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Deep Vein thrombosis
# INPUT TO VADER ['@united', 'Deep', 'Vein', 'thrombosis']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I’m a small guy
# INPUT TO VADER ['"', '@united', 'I', 'know', '.', 'I', '’m', 'sure', 'you', 'hear', 'it', 'all', 'the', 'time', '—', 'do', 'n’t', 'like', 'the', 'new', 'seat', '.', 'I', '’m', 'a', 'small', 'guy']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.78, 'pos': 0.22, 'compound': 0.5859}
#
# INPUT SENTENCE #ExceptionalService
# INPUT TO VADER ['@jetblue', 'thank', 'you', 'Alicia', '!', ' ', '#', 'ExceptionalService']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.589, 'pos': 0.411, 'compound': 0.4199}
#
# INPUT SENTENCE @united #worst2unitedflightsever UA 236 LAS to IAD 2/24 mechanical problems again - took off - had to land for fix - delayed again #wtfodds!
# INPUT TO VADER ['@united', '#', 'worst2unitedflightsever', 'UA', '236', 'LAS', 'to', 'IAD', '2/24', 'mechanical', 'problem', 'again', '-', 'take', 'off', '-', 'have', 'to', 'land', 'for', 'fix', '-', 'delay', 'again', '#', 'wtfodd', '!']
# VADER OUTPUT {'neg': 0.218, 'neu': 0.782, 'pos': 0.0, 'compound': -0.6476}
#
# INPUT SENTENCE @VirginAmerica to begin Dallas-Austin #flights in April - 88.9 KETR http://t.co/SSUVWwkyHH
# INPUT TO VADER ['@VirginAmerica', 'to', 'begin', 'Dallas', '-', 'Austin', '#', 'flight', 'in', 'April', '-', '88.9', 'KETR', 'http://t.co/ssuvwwkyhh']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Not cool http://t.co/6KpyhckA9l
# INPUT TO VADER ['@united', '-', '3', 'of', '6', 'first', 'seat', 'open', 'on', 'UA5097', '.', 'no', 'upgrade', 'process', '.', 'Gate', 'agent', '@yyz', 'say', 'their', 'too', 'busy', '.', 'not', 'cool', 'http://t.co/6KpyhckA9l']
# VADER OUTPUT {'neg': 0.188, 'neu': 0.812, 'pos': 0.0, 'compound': -0.4874}
#
# INPUT SENTENCE Quick
# INPUT TO VADER ['"', '@VirginAmerica', 'thank', 'you', 'for', 'the', 'easy', 'itinerary', 'shift', 'for', 'impend', 'weather', '.', 'quick']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'compound': 0.6597}
#
# INPUT SENTENCE @SouthwestAir you have open seats on flight 4001 pvd to MCO @ 1215pm today?
# INPUT TO VADER ['@southwestair', 'you', 'have', 'open', 'seat', 'on', 'flight', '4001', 'pvd', 'to', 'MCO', '@', '1215pm', 'today', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Norfolk… http://t.co/TgSLjjN6g0
# INPUT TO VADER ['@southwestair', 'thank', 'for', 'take', 'it', 'up', 'a', 'notch', '!', '!', 'leinenkugel', '#', 'craftbeer', '#', 'goodflight', '@', 'Norfolk', '…', 'http://t.co/tgsljjn6g0']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.4738}
#
# INPUT SENTENCE #flythefriendlyskies
# INPUT TO VADER ['@united', 'CDG', '-', 'LAS', '42', 'hour', '.', 'and', 'my', 'luggage', 'be', 'in', 'SFO', '.', 'I', 'have', 'be', 'wear', 'the', 'same', 'clothe', 'for', '42', 'hour', '.', 'thank', 'you', '.', '#', 'flythefriendlyskie']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.898, 'pos': 0.102, 'compound': 0.3612}
#
# INPUT SENTENCE I'm looking at 3/19-3/23
# INPUT TO VADER ['@southwestair', 'be', 'there', 'any', 'flight', 'from', 'MSP', 'to', 'HRL', 'in', 'March', '?', 'I', 'be', 'look', 'at', '3/19', '-', '3/23']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue to End Partnership with American Express - http://t.co/WhuFmI2Ytd http://t.co/fbTEMFwRsP
# INPUT TO VADER ['@jetblue', 'to', 'End', 'Partnership', 'with', 'American', 'Express', '-', 'http://t.co/WhuFmI2Ytd', 'http://t.co/fbtemfwrsp']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@AmericanAir Joanna is wonderful
# INPUT TO VADER ['"', '@americanair', 'Joanna', 'be', 'wonderful']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.448, 'pos': 0.552, 'compound': 0.5719}
#
# INPUT SENTENCE https://t.co/caf2cx3gfi"
# INPUT TO VADER ['"', '@united', '"', '"', 'we', 'like', 'hear', 'from', 'you', '.', '"', '"', 'so', 'why', 'have', 'not', 'you', 'reply', 'to', 'my', 'tweet', 'and/or', 'email', 'yet', '?', 'https://t.co/caf2cx3gfi', '"']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.878, 'pos': 0.122, 'compound': 0.3612}
#
# INPUT SENTENCE "@SouthwestAir not frustrated
# INPUT TO VADER ['"', '@southwestair', 'not', 'frustrate']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.446, 'pos': 0.554, 'compound': 0.357}
#
# INPUT SENTENCE I'll send it over when you follow.
# INPUT TO VADER ['@southwestair', 'that', 'would', 'be', 'great', '.', 'thank', 'you', '!', 'I', 'will', 'send', 'it', 'over', 'when', 'you', 'follow', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.635, 'pos': 0.365, 'compound': 0.784}
#
# INPUT SENTENCE Unhappy customer.
# INPUT TO VADER ['@unite', 'on', '4124', 'arrive', 'two', 'hour', 'late', 'flight', 'into', 'CLT', '.', 'now', 'sit', 'on', 'the', 'tarmac', 'while', 'they', 'move', 'a', 'plane', 'from', 'the', 'gate', '.', 'unhappy', 'customer', '.']
# VADER OUTPUT {'neg': 0.109, 'neu': 0.891, 'pos': 0.0, 'compound': -0.4215}
#
# INPUT SENTENCE :)
# INPUT TO VADER ['@JetBlue', 'Flight', 'Booking', 'Problems', 'flight', 'for', 'a', 'DC', 'visit', 'for', 'Easter', 'weekend', 'start', 'difficult', 'but', 'end', 'well', 'with', 'you', 'guy', '!', 'big', 'fan', 'here', '.', ':)']
# VADER OUTPUT {'neg': 0.114, 'neu': 0.572, 'pos': 0.314, 'compound': 0.807}
#
# INPUT SENTENCE @JetBlue they were amazing and thank you!
# INPUT TO VADER ['@jetblue', 'they', 'be', 'amazing', 'and', 'thank', 'you', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.431, 'pos': 0.569, 'compound': 0.7644}
#
# INPUT SENTENCE "@united after 2 days - 1 flight Cancelled Flightled
# INPUT TO VADER ['"', '@unite', 'after', '2', 'day', '-', '1', 'flight', 'cancel', 'flightle']
# VADER OUTPUT {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.25}
#
# INPUT SENTENCE @JetBlue any thoughts on waiver of change fees for travel out of Boston this weekend?
# INPUT TO VADER ['@jetblue', 'any', 'thought', 'on', 'waiver', 'of', 'change', 'fee', 'for', 'travel', 'out', 'of', 'Boston', 'this', 'weekend', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@SouthwestAir I have a credit that expires a month before my flight
# INPUT TO VADER ['"', '@southwestair', 'I', 'have', 'a', 'credit', 'that', 'expire', 'a', 'month', 'before', 'my', 'flight']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'compound': 0.3818}
#
# INPUT SENTENCE Thats 3 6+ hour flight delays in 2 weeks
# INPUT TO VADER ['@unite', 'that', 's', 'because', 'you', 'do', 'not', 'read', 'my', 'entire', 'tweet', '.', 'Wife', "'s", '12', 'pm', 'flight', 'be', 'now', 'delay', 'to', '6:30', '.', ' ', 'that', 's', '3', '6', '+', 'hour', 'flight', 'delay', 'in', '2', 'week']
# VADER OUTPUT {'neg': 0.161, 'neu': 0.839, 'pos': 0.0, 'compound': -0.5574}
#
# INPUT SENTENCE "@VirginAmerica - amazing customer  service
# INPUT TO VADER ['"', '@virginamerica', '-', 'amazing', 'customer', ' ', 'service']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.441, 'pos': 0.559, 'compound': 0.5859}
#
# INPUT SENTENCE http://t.co/WmX12F33ZC
# INPUT TO VADER ['@jetblue', 'whatever', 'your', 'lil', '#', 'mint', 'heart', 'desire', '!', 'http://t.co/wmx12f33zc']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.701, 'pos': 0.299, 'compound': 0.4574}
#
# INPUT SENTENCE Apply here: http://t.co/jLHM0x7UkB
# INPUT TO VADER ['@SouthwestAir', 'be', 'hire', 'for', 'their', 'Emerging', 'Leader', 'Development', 'Program-', 'last', 'day', 'to', 'apply', 'be', 'today', '!', 'apply', 'here', ':', 'http://t.co/jlhm0x7ukb']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Could you please follow me so i can dm you?
# INPUT TO VADER ['@USAirways', 'Hi', '-', 'I', 'have', 'a', 'travel', 'question', '.', 'could', 'you', 'please', 'follow', 'I', 'so', 'I', 'can', 'dm', 'you', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.3182}
#
# INPUT SENTENCE Excited to be working with you guys!
# INPUT TO VADER ['@united', 'thank', 'you', '!', 'excited', 'to', 'be', 'work', 'with', 'you', 'guy', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.593, 'pos': 0.407, 'compound': 0.6688}
#
# INPUT SENTENCE @united give me an email address and I'll send the actually screen shot to you.
# INPUT TO VADER ['@united', 'give', 'I', 'an', 'email', 'address', 'and', 'I', 'will', 'send', 'the', 'actually', 'screen', 'shoot', 'to', 'you', '.']
# VADER OUTPUT {'neg': 0.156, 'neu': 0.844, 'pos': 0.0, 'compound': -0.34}
#
# INPUT SENTENCE I mean…it is a great card 😀
# INPUT TO VADER ['@southwestair', 'oh', 'no', 'worry', '.', 'just', 'have', 'never', 'see', 'that', 'before', 'until', 'today', '.', 'I', 'mean', '…', 'it', 'be', 'a', 'great', 'card', '😀']
# VADER OUTPUT {'neg': 0.22, 'neu': 0.603, 'pos': 0.177, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue with 3 kids and 11 days 340 + doesn't work and it's months in advance
# INPUT TO VADER ['@jetblue', 'with', '3', 'kid', 'and', '11', 'day', '340', '+', 'do', 'not', 'work', 'and', 'it', 'be', 'month', 'in', 'advance']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Before
# INPUT TO VADER ['"', '@united', 'your', 'new', 'mileage', 'policy', 'be', 'awful', '.', 'before']
# VADER OUTPUT {'neg': 0.3, 'neu': 0.7, 'pos': 0.0, 'compound': -0.4588}
#
# INPUT SENTENCE @united involuntarily bumped your passenger and can't guarantee them another flight for three days!
# INPUT TO VADER ['@united', 'involuntarily', 'bump', 'your', 'passenger', 'and', 'can', 'not', 'guarantee', 'they', 'another', 'flight', 'for', 'three', 'day', '!']
# VADER OUTPUT {'neg': 0.127, 'neu': 0.873, 'pos': 0.0, 'compound': -0.2575}
#
# INPUT SENTENCE @SouthwestAir if I am enrolled in the ATL companion pass offer and booked 3 flights already before May 17 when can I start using the pass?
# INPUT TO VADER ['@SouthwestAir', 'if', 'I', 'be', 'enrol', 'in', 'the', 'ATL', 'companion', 'pass', 'offer', 'and', 'book', '3', 'flight', 'already', 'before', 'May', '17', 'when', 'can', 'I', 'start', 'use', 'the', 'pass', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways Thank you!
# INPUT TO VADER ['@usairway', 'thank', 'you', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'compound': 0.4199}
#
# INPUT SENTENCE @SouthwestAir looking for cheap flight to vegas
# INPUT TO VADER ['@southwestair', 'look', 'for', 'cheap', 'flight', 'to', 'vegas']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Great job American!
# INPUT TO VADER ['@AmericanAir', 'aa2416', 'on', 'time', 'and', 'awesome', 'flight', '.', 'great', 'job', 'American', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.485, 'pos': 0.515, 'compound': 0.8588}
#
# INPUT SENTENCE @JetBlue thank you!!
# ...
# VADER OUTPUT {'neg': 0.0, 'neu': 0.735, 'pos': 0.265, 'compound': 0.6884}
#
# INPUT SENTENCE We'll see about that tomorrow morning when I have to fight for a seat.
# INPUT TO VADER ['@jetblue', 'be', 'that', 'a', 'guarantee', '?', 'we', 'will', 'see', 'about', 'that', 'tomorrow', 'morning', 'when', 'I', 'have', 'to', 'fight', 'for', 'a', 'seat', '.']
# VADER OUTPUT {'neg': 0.133, 'neu': 0.765, 'pos': 0.102, 'compound': -0.1531}
#
# INPUT SENTENCE @USAirways following you now
# INPUT TO VADER ['@usairway', 'follow', 'you', 'now']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE When will u guys learn?
# INPUT TO VADER ['@unite', 'well', 'the', 'bar', 'be', 'set', 'low', '!', 'you', 'guy', 'be', 'really', 'good', 'at', 'the', 'apology', 'game', '!', 'what', 'will', 'change', '?', 'when', 'will', 'u', 'guy', 'learn', '?']
# VADER OUTPUT {'neg': 0.074, 'neu': 0.666, 'pos': 0.261, 'compound': 0.6527}
#
# INPUT SENTENCE "@AmericanAir Next Friday
# INPUT TO VADER ['"', '@americanair', 'next', 'Friday']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #DestinationDragons
# INPUT TO VADER ['@southwestair', 'when', 'do', 'today', "'s", 'scavenger', 'hunt', 'start', '?', 'I', 'be', 'try', 'to', 'help', 'my', 'little', 'brother', 'win', '!', '#', 'destinationdragon']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.697, 'pos': 0.303, 'compound': 0.7589}
#
# INPUT SENTENCE We are finally at the gate.
# INPUT TO VADER ['@jetblue', 'thank', 'you', '.', 'we', 'be', 'finally', 'at', 'the', 'gate', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'compound': 0.3612}
#
# INPUT SENTENCE As a business owner
# INPUT TO VADER ['"', '@unite', 'not', 'even', 'mention', 'how', 'rude', 'the', 'customer', 'service', 'be', 'to', 'we', '.', 'as', 'a', 'business', 'owner']
# VADER OUTPUT {'neg': 0.176, 'neu': 0.824, 'pos': 0.0, 'compound': -0.4588}
#
# INPUT SENTENCE Yeah cold
# INPUT TO VADER ['"', '@AmericanAir', '@dfwairport', 'that', 'be', 'DFW', '!', '?', 'OMG', '!', 'yeah', 'cold']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.715, 'pos': 0.285, 'compound': 0.4184}
#
# INPUT SENTENCE A+ service!
# INPUT TO VADER ['@jetblue', 'love', 'you', 'guy', 'sooooooo', 'much', '.', 'ridiculously', 'appreciate', '!', 'A+', 'service', '!']
# VADER OUTPUT {'neg': 0.142, 'neu': 0.415, 'pos': 0.443, 'compound': 0.7256}
#
# INPUT SENTENCE @VirginAmerica i would like help with some flights please.
# INPUT TO VADER ['@VirginAmerica', 'I', 'would', 'like', 'help', 'with', 'some', 'flight', 'please', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.4, 'pos': 0.6, 'compound': 0.7579}
#
# INPUT SENTENCE @SouthwestAir loving the boarding to go to Chicago #KeepItMovin'
# INPUT TO VADER ['@southwestair', 'love', 'the', 'boarding', 'to', 'go', 'to', 'Chicago', '#', 'KeepItMovin', "'"]
# VADER OUTPUT {'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.6369}
#
# INPUT SENTENCE Thank you!
# INPUT TO VADER ['@unite', 'the', 'upgrade', 'to', 'first', 'class', 'be', 'a', 'nice', 'way', 'to', 'fix', 'your', 'early', 'mistake', '.', 'thank', 'you', '!']
# VADER OUTPUT {'neg': 0.114, 'neu': 0.619, 'pos': 0.266, 'compound': 0.4926}
#
# INPUT SENTENCE #oscars2016
# INPUT TO VADER ['@united', 'you', 'be', 'my', 'early', 'frontrunner', 'for', 'good', 'airline', '!', '#', 'oscars2016']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.4926}
#
# INPUT SENTENCE Is there a UK number I could try?
# INPUT TO VADER ['@usairway', 'I', 'be', 'a', 'UK', 'citizen', '.', 'be', 'there', 'a', 'UK', 'number', 'I', 'could', 'try', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.874, 'pos': 0.126, 'compound': 0.0772}
#
# INPUT SENTENCE "@united has not responded to my various requests for contact numbers
# INPUT TO VADER ['"', '@united', 'have', 'not', 'respond', 'to', 'my', 'various', 'request', 'for', 'contact', 'number']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.885, 'pos': 0.115, 'compound': 0.0772}
#
# INPUT SENTENCE "@AmericanAir I love very much your planes
# INPUT TO VADER ['"', '@americanair', 'I', 'love', 'very', 'much', 'your', 'plane']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.543, 'pos': 0.457, 'compound': 0.6369}
#
# INPUT SENTENCE Thank you!!!
# INPUT TO VADER ['@VirginAmerica', 'and', 'again', '!', 'another', 'rep', 'kick', 'butt', '!', 'Naelah', 'represent', 'your', 'team', 'so', 'beautifully', '!', '!', 'thank', 'you', '!', '!', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.599, 'pos': 0.401, 'compound': 0.8654}
#
# INPUT SENTENCE Haven't heard back and I'm flying this week #disappointed
# INPUT TO VADER ['@VirginAmerica', ' ', 'I', 'apply', 'over', '2', 'week', 'ago', '.', 'have', 'not', 'hear', 'back', 'and', 'I', 'be', 'fly', 'this', 'week', '#', 'disappoint']
# VADER OUTPUT {'neg': 0.162, 'neu': 0.838, 'pos': 0.0, 'compound': -0.4019}
#
# INPUT SENTENCE Never been on ur planes but now I will!!
# INPUT TO VADER ['@VirginAmerica', 'this', 'be', 'too', 'cool', '!', ' ', 'never', 'be', 'on', 'ur', 'plane', 'but', 'now', 'I', 'will', '!', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.826, 'pos': 0.174, 'compound': 0.3666}
#
# INPUT SENTENCE "@JetBlue yes
# INPUT TO VADER ['"', '@jetblue', 'yes']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.27, 'pos': 0.73, 'compound': 0.4019}
#
# INPUT SENTENCE It would mean so much to me #DestinationDragons
# INPUT TO VADER ['@southwestair', 'be', 'there', 'anything', 'I', 'can', 'do', 'to', 'get', 'ticket', 'for', '@imaginedragon', 'at', '@vinylvega', '?', 'it', 'would', 'mean', 'so', 'much', 'to', 'I', '#', 'destinationdragon']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #travel #friendlyteam
# INPUT TO VADER ['@USAirways', 'great', 'job', 'today', 'from', 'your', 'team', 'with', 'a', 'challenging', 'weather', 'delay', 'on', 'flight', '1925', 'out', 'of', 'Charlotte', '.', '#', 'travel', '#', 'friendlyteam']
# VADER OUTPUT {'neg': 0.096, 'neu': 0.667, 'pos': 0.237, 'compound': 0.5267}
#
# INPUT SENTENCE @united sent DM's
# INPUT TO VADER ['@united', 'send', 'DM', "'s"]
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united oh
# INPUT TO VADER ['"', '@united', 'oh']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Apart from being on hold for over 2 hours and having talked to 5 people and the problem still not resolved!
# INPUT TO VADER ['@united', 'apart', 'from', 'be', 'on', 'hold', 'for', 'over', '2', 'hour', 'and', 'having', 'talk', 'to', '5', 'people', 'and', 'the', 'problem', 'still', 'not', 'resolve', '!']
# VADER OUTPUT {'neg': 0.223, 'neu': 0.777, 'pos': 0.0, 'compound': -0.6341}
#
# INPUT SENTENCE http://t.co/dxn58rxDkS”@jameskraw see.
# INPUT TO VADER ['"', '@jetblue', ':', 'our', 'fleet', 'be', 'on', 'fleek', '.', 'http://t.co/dxn58rxdks”@jameskraw', 'see', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways thanks.
# INPUT TO VADER ['@USAirways', 'thank', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'compound': 0.3612}
#
# INPUT SENTENCE @SouthwestAir  how do you get one?
# INPUT TO VADER ['@SouthwestAir', ' ', 'how', 'do', 'you', 'get', 'one', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Now we are waiting for a flight attendant as one just walked off &amp; left http://t.co/IpaamZT7Z2
# INPUT TO VADER ['@united', 'I', 'would', 'like', 'a', 'supervisor', 'to', 'talk', 'to', '.', 'now', 'we', 'be', 'wait', 'for', 'a', 'flight', 'attendant', 'as', 'one', 'just', 'walk', 'off', '&', 'amp', ';', 'leave', 'http://t.co/IpaamZT7Z2']
# VADER OUTPUT {'neg': 0.051, 'neu': 0.844, 'pos': 0.105, 'compound': 0.3182}
#
# INPUT SENTENCE @VirginAmerica what is your policy on flying after surgery?
# INPUT TO VADER ['@VirginAmerica', 'what', 'be', 'your', 'policy', 'on', 'fly', 'after', 'surgery', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united it's 9:56
# INPUT TO VADER ['"', '@united', 'it', 'be', '9:56']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@United Right now at Tropic Air in San Pedro
# INPUT TO VADER ['"', '@united', 'right', 'now', 'at', 'Tropic', 'Air', 'in', 'San', 'Pedro']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Can you tell me Jet Airways award availability?
# INPUT TO VADER ['@united', 'can', 'you', 'tell', 'I', 'Jet', 'Airways', 'award', 'availability', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.5423}
#
# INPUT SENTENCE NYC was awesomeee!
# INPUT TO VADER ['@jetblue', 'love', 'travel', 'with', 'Jetblue', '.', 'can', 'not', 'wait', 'to', 'go', 'to', 'Paris', 'oui', 'oui', '!', '!', '!', 'NYC', 'be', 'awesomeee', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.749, 'pos': 0.251, 'compound': 0.7482}
#
# INPUT SENTENCE With a group and over 20 luggages are lost
# INPUT TO VADER ['@unite', 'where', 'be', 'our', 'luggage', '?', 'with', 'a', 'group', 'and', 'over', '20', 'luggage', 'be', 'lose']
# VADER OUTPUT {'neg': 0.184, 'neu': 0.816, 'pos': 0.0, 'compound': -0.4019}
#
# INPUT SENTENCE I'm running iOS 8.1.3
# INPUT TO VADER ['@americanair', 'yes', 'to', 'the', 'iOS', '.', 'I', 'be', 'run', 'ios', '8.1.3']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.4019}
#
# INPUT SENTENCE Extremely unlikely I will make it!
# INPUT TO VADER ['@united', 'Flight', 'have', 'be', 'delay', 'for', 'another', 'hour', 'so', 'only', 'have', '24', 'min', 'to', 'transit', 'at', 'LAX', '...', 'extremely', 'unlikely', 'I', 'will', 'make', 'it', '!']
# VADER OUTPUT {'neg': 0.105, 'neu': 0.895, 'pos': 0.0, 'compound': -0.3802}
#
# INPUT SENTENCE @united it's disgusting and unconscionable the treatment I've received tonight.
# INPUT TO VADER ['@united', 'it', 'be', 'disgusting', 'and', 'unconscionable', 'the', 'treatment', 'I', 'have', 'receive', 'tonight', '.']
# VADER OUTPUT {'neg': 0.254, 'neu': 0.746, 'pos': 0.0, 'compound': -0.5267}
#
# INPUT SENTENCE 25 min. @ABC11_WTVD
# INPUT TO VADER ['@united', '25', 'minute', 'hold', 'be', '1', 'hr', '.', '25', 'min', '.', '@ABC11_WTVD']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Fingers Crossed!
# INPUT TO VADER ['@southwestair', '#', 'DestinationDragons', 'any', 'word', 'on', 'winner', 'of', 'contest', '?', 'any', 'chance', 'for', 'tix', 'for', 'the', 'Provo', 'DestinationDragons', 'show', '?', 'finger', 'cross', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.725, 'pos': 0.275, 'compound': 0.7545}
#
# INPUT SENTENCE http://t.co/3zpJr7kWbk
# INPUT TO VADER ['@united', 'should', 'contact', 'I', 'and', 'the', 'other', 'on', 'my', 'flight', 'who', 'can', 'not', 'get', 'their', 'website', 'to', 'work', '.', 'none', 'of', 'our', 'info', 'be', 'valid', '!', 'http://t.co/3zpjr7kwbk']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue will we be able to watch the Oscars on our flight tomorrow?
# INPUT TO VADER ['@jetblue', 'will', 'we', 'be', 'able', 'to', 'watch', 'the', 'Oscars', 'on', 'our', 'flight', 'tomorrow', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Just double checking bc the site looked different.
# INPUT TO VADER ['@jetblue', 'receive', 'an', 'invitation', 'to', 'participate', 'in', 'e', '-', 'reward', '.', 'be', 'this', 'legit', 'from', 'JetBlue', '?', 'just', 'double', 'check', 'bc', 'the', 'site', 'look', 'different', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.844, 'pos': 0.156, 'compound': 0.5719}
#
# INPUT SENTENCE @united I want a hotel room and a whiskey.
# INPUT TO VADER ['@united', 'I', 'want', 'a', 'hotel', 'room', 'and', 'a', 'whiskey', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.0772}
#
# INPUT SENTENCE "@JetBlue Well
# INPUT TO VADER ['"', '@JetBlue', 'well']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.323, 'pos': 0.677, 'compound': 0.2732}
#
# INPUT SENTENCE @JetBlue but Virgin has wifi 👀
# INPUT TO VADER ['@jetblue', 'but', 'Virgin', 'have', 'wifi', '👀']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE You should be very proud :) http://t.co/oKtUkjY92O (via @ParachuteGuy)
# INPUT TO VADER ['@unite', 'what', 'a', 'really', 'GREAT', '&', 'amp', ';', 'flattering', 'story', 'about', 'you', '!', 'you', 'should', 'be', 'very', 'proud', ':)', 'http://t.co/oktukjy92o', '(', 'via', '@parachuteguy', ')']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.489, 'pos': 0.511, 'compound': 0.9398}
#
# INPUT SENTENCE I was stuck for 35 hours because of you guys
# INPUT TO VADER ['@united', 'I', 'try', 'but', 'no', 'one', 'be', 'available', 'in', 'bogota', 'and', 'everyone', 'be', 'rude', 'in', 'Houston', '.', 'I', 'be', 'stick', 'for', '35', 'hour', 'because', 'of', 'you', 'guy']
# VADER OUTPUT {'neg': 0.236, 'neu': 0.764, 'pos': 0.0, 'compound': -0.7783}
#
# INPUT SENTENCE @JetBlue Sent.
# INPUT TO VADER ['@JetBlue', 'Sent', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways can you help me reroute my trip?
# INPUT TO VADER ['@usairway', 'can', 'you', 'help', 'I', 'reroute', 'my', 'trip', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.4019}
#
# INPUT SENTENCE I'd like to call them myself.
# INPUT TO VADER ['@unite', 'what', 'delivery', 'service', 'do', 'you', 'use', '?', 'I', 'would', 'like', 'to', 'call', 'they', 'myself', '.']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.3612}
#
# INPUT SENTENCE @SouthwestAir Arkansas Gov. plans to sign Governor SB-202 that legalizes discrimination of LGBT.Can you lend your voice to a state boycott?
# INPUT TO VADER ['@SouthwestAir', 'Arkansas', 'Gov.', 'plan', 'to', 'sign', 'Governor', 'SB-202', 'that', 'legalize', 'discrimination', 'of', 'lgbt.can', 'you', 'lend', 'your', 'voice', 'to', 'a', 'state', 'boycott', '?']
# VADER OUTPUT {'neg': 0.108, 'neu': 0.892, 'pos': 0.0, 'compound': -0.3182}
#
# INPUT SENTENCE Can this get any worse.
# INPUT TO VADER ['@united', 'OMG', '!', '!', '!', 'you', 'just', 'bump', 'I', 'off', 'the', 'last', 'flight', '.', 'can', 'this', 'get', 'any', 'bad', '.']
# VADER OUTPUT {'neg': 0.252, 'neu': 0.748, 'pos': 0.0, 'compound': -0.6571}
#
# INPUT SENTENCE I’ll look forward to hopefully one of those 103 on my flight home tonight :)
# INPUT TO VADER ['@jetblue', 'credit', 'to', 'you', 'for', 'reply', '.', ' ', 'I', '’ll', 'look', 'forward', 'to', 'hopefully', 'one', 'of', 'those', '103', 'on', 'my', 'flight', 'home', 'tonight', ':)']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.684, 'pos': 0.316, 'compound': 0.8074}
#
# INPUT SENTENCE "@united hi JP
# INPUT TO VADER ['"', '@united', 'hi', 'jp']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.2023}
#
# INPUT SENTENCE Thanks a lot!!
# INPUT TO VADER ['@united', 'my', 'flight', 'be', 'suppose', 'to', 'depart', 'to', 'Boston', 'at', '4:36', 'and', 'now', 'it', 'be', 'depart', 'at', '6:30', 'due', 'to', 'issue', 'with', 'find', 'a', 'pilot', '.', 'thank', 'a', 'lot', '!', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compound': 0.4738}
#
# INPUT SENTENCE @USAirways is a DM possible if you aren't following me?
# INPUT TO VADER ['@USAirways', 'be', 'a', 'DM', 'possible', 'if', 'you', 'be', 'not', 'follow', 'I', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE To top things off
# INPUT TO VADER ['"', '@united', 'ok', '.', 'to', 'top', 'thing', 'off']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.4588}
#
# INPUT SENTENCE @SouthwestAir safety back in Dallas!
# INPUT TO VADER ['@southwestair', 'safety', 'back', 'in', 'Dallas', '!']
# VADER OUTPUT {'neg': 0.0, 'neu': 0.564, 'pos': 0.436, 'compound': 0.4753}
#
# INPUT SENTENCE @SouthwestAir I'm flying out of CUN tomorrow To DEN - can I change my flight due to the travel advisory??
# INPUT TO VADER ['@southwestair', 'I', 'be', 'fly', 'out', 'of', 'CUN', 'tomorrow', 'to', 'den', '-', 'can', 'I', 'change', 'my', 'flight', 'due', 'to', 'the', 'travel', 'advisory', '?', '?']
# VADER OUTPUT {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
for sentence in airline_tweets_train.data:
    adjective_text = sentence.decode("utf-8")
    run_vader(adjective_text, lemmatize=True, parts_of_speech_to_consider={'JJ'}, verbose=1)
# Out:
# INPUT SENTENCE Just wondering.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united next day
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@JetBlue Thank you that it is not just a livery; it is a culture that 16
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir I cannot DM you as you do not follow me.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@VirginAmerica Funny story
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united flight 403 is delayed 40 min bc a missing screw and were in danger of missing flight 6491
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @AmericanAir does it show that we are on the same plane?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Just sayin'.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united what's a good number to call to speak with someone about how you can fix what you did to 50 people and their luggage on Saturday?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Could Reservations help me?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united never fails
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united hi guys
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united broken light
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE (2/2)
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united love the new 1st class breakfast!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@USAirways just heard #Monterey airport was closed due to thick fog
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I have to book today.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I'll figure out car rental changes and such.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE And yes
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #GetMartyHome
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir nice touch on the passbook integration!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Keep it up :) @AmericanAir
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE thank you so much!!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways any chance of a travel advisory or DCA this weekend?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE But great agents in savannah!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@JetBlue Flight 152 (N559JB) ""Here's Looking at Blue Kid"" departs @MCO enroute to @BostonLogan http://t.co/qeaDA92MW6"
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united diverged to Burlington
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united thank you for taking care of my mom and reFlight Booking Problems her flight in phl.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united thanks we'll be in touch!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united line full of worried customers and guy at desk says so sorry you will have to take care of your problems Late Flightr I don't have time.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united my flight is Late Flight due to mechanical issues 3 of 4 flights in past 10 days!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united please arrange someone at the arriving gate of flight 5957 to Chicago for either a refund or first class upgrade
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE each united employee
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE On a good note
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE http://t.co/dN1if2cGwE
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united if you're going to Cancelled Flight flights today
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @AmericanAir drop me a follow I need help
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE http://t.co/mpi4yuo9jR” Oh word!!!!??????
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@VirginAmerica has getaway deals through May
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir iPhone App Adds Passbook Support #Airlines #Travel http://t.co/lJzDTHD9Bv
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Just a second.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Send Bloody Mary's to row 27!!!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Pretty ridiculous.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Good #customerservice is dead."
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@VirginAmerica I rang
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Can we combine res?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I am being told that I am asking for a refund on a used ticket on a flight that got Cancelled Flightled how is the ticket used?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Never ever flying United again #joke
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united if I was rebooked do I have to pick up my luggage?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Super professional!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Or at least prepared with a gate when we land!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE And to @PamGrout for positive thoughts.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united Late Flight 2014 and 2015 are huge step towards decline in service
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Denver to LAX and it's wonderful!!!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@VirginAmerica I spoke with a representative that offered no solution
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Can I DM you the info?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united if I miss the #Oscars I'll never fly united again
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue is definitely my new favorite airline.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Thanks!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE All good now.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE united has no baby meals
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @AmericanAir OK I will call them likely tmrw UK time to question the process getting the change charge reversed due to a bereavement
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE You made the difficult weather days proficient and enjoyable.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Mind if I ask
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Thanks!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE ^EY”
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE http://t.co/2nY5TuXFqf
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE and how does one obtain this companion pass?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united SATURDAY this morning Man dies from Ebola http://t.co/hXVVIS0VWw
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "Thank you
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@JetBlue can your people working this contact me
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Or we could just delay :/
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #UnitedAirlines
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united so going forward
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE sent
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE http://t.co/dSDEbodmEL
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE http://t.co/bNgpli8JT6
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united this is atrocious customer service.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@AmericanAir sure
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I have to be refunded whenever I get at my final destination or not!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@SouthwestAir oops
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Why do I have to play for hotel tonight in #ewr?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@AmericanAir I have a couple questions for you
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "Nice RT @VirginAmerica: The man of steel might be faster
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir how are flights looking for tomorrow morning from #Nashville (BNA) to Fort Lauderdale (FLL) ?!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE this experience just keeps getting worse and worse
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Great people at your call center!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Im so Flight Booking Problems my next flight with you!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united your first class is a joke
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Hope to be flying with you guys soon!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united enough already with the poor service
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united I wasn't asking for a full refund but delaying me 3 hours and giving no reason should be enough to give partial credit
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue thank you!!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Thank you!!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE As of yet
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Thank you.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united another awesome new plane flight 1584 and extremely nice Captain Steve Connolly.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE NEVER AGAIN with @united
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir yes please
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united I was insulted
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @virginamerica may start service to Hawaii from #SanFrancisco this year http://t.co/yPo7nYpRZl #biztravel
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united @czamkoff It's all about profit
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Left us in the cold in DEN.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #ua1523
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united what
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE contact http://t.co/aQjn4HwNaC  we negotiate resolutions for You!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @AmericanAir @dfwairport you 2 together are the best part of flying!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #veryimportantproject
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE http://t.co/aypyaDUY6a
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Although the wait was long due to weather r/scheduling
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Pleased to be a Premier Platinum
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @AmericanAir is that the flight for tomorrow?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Another awful experience and Victoria at the check in desk in STL could not have been more rude and condescending.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united thanks
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Thank you for providing one bright spot in a frustrating situation.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united boarding was decent
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE keep your paper work ready and don't delay our flights(#1585)and meetings @ChooseChicago
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I appreciate you working with me
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Unacceptable
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Not waste their time?!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @AmericanAir followback
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@VirginAmerica Anytime
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways in a few weeks
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue Seems very likely.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @AmericanAir can I send you my trusted traveler ID to add to my reservation for tsa pre?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Was told ""we can't find a supervisor."""
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE NEVER AGAIN!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @VirginAmerica your beautiful front-end design is down right now; but it was cool to still book my ticket b/c all your back-end was secure.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE r lying how can I help
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@JetBlue's CEO #pilots among ardent fans
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir can you help
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united they did on a delta flight out of LAX which is why I should be compensated for my rental car there.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir https://t.co/OQUKSo3s2O subscribe please https://t.co/OQUKSo3s2O
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united look at this beauty 😉 dc 10 united airlines 😉 http://t.co/MvYoizRPdE
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@JetBlue quick question
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@VirginAmerica can't check in
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united After an hour+ wait
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Deep Vein thrombosis
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I’m a small guy
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #ExceptionalService
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united #worst2unitedflightsever UA 236 LAS to IAD 2/24 mechanical problems again - took off - had to land for fix - delayed again #wtfodds!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @VirginAmerica to begin Dallas-Austin #flights in April - 88.9 KETR http://t.co/SSUVWwkyHH
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Not cool http://t.co/6KpyhckA9l
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Quick
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir you have open seats on flight 4001 pvd to MCO @ 1215pm today?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Norfolk… http://t.co/TgSLjjN6g0
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #flythefriendlyskies
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I'm looking at 3/19-3/23
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue to End Partnership with American Express - http://t.co/WhuFmI2Ytd http://t.co/fbTEMFwRsP
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@AmericanAir Joanna is wonderful
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE https://t.co/caf2cx3gfi"
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@SouthwestAir not frustrated
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I'll send it over when you follow.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Unhappy customer.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE :)
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue they were amazing and thank you!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united after 2 days - 1 flight Cancelled Flightled
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue any thoughts on waiver of change fees for travel out of Boston this weekend?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@SouthwestAir I have a credit that expires a month before my flight
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Thats 3 6+ hour flight delays in 2 weeks
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@VirginAmerica - amazing customer  service
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE http://t.co/WmX12F33ZC
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Apply here: http://t.co/jLHM0x7UkB
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Could you please follow me so i can dm you?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Excited to be working with you guys!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united give me an email address and I'll send the actually screen shot to you.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I mean…it is a great card 😀
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue with 3 kids and 11 days 340 + doesn't work and it's months in advance
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Before
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united involuntarily bumped your passenger and can't guarantee them another flight for three days!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir if I am enrolled in the ATL companion pass offer and booked 3 flights already before May 17 when can I start using the pass?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways Thank you!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir looking for cheap flight to vegas
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Great job American!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue thank you!!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united 5.5 hours Late Flightr I've been in transit for a total of twelve hours...please just change the plane on flight 600 this is ridiculous SFO
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Flight 51 from BOS to MCO
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united and what am I suppose to do with that number?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Not sure why this happened.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE y'all are ALL RIGHT with me!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united that's what I tried to do
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @AmericanAir thank you for the update!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @CNN
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways do you have an email??
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Can u 2? #goodenoughmother
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Have a nice evening.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united is the worst
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue Love you guys😍😍😍 http://t.co/3X9NRUOvtS
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united since bulkhead seats cannot have bags on floor
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united customer service what's That???
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE IF so
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I've gotten no help from you tonight.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE it's our honeymoon and this delay you has put a damper on iy
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir App Updated With #Passbook Support http://t.co/WrWqrUblPs via @ubergizmo
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE http://t.co/XX5QSCjlL1” @BrandsSayingBae #Freberg15
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #iflyalot #bs
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue when are you going to get wifi on your planes?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE You clearly don't care about your customers.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Customer service ❌ http://t.co/qP6Aw3nLIP
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir when are you starting routes to #Hawaii and #Canada?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue can I switch my seat for my trip on Sunday?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Tickets needed fixing again another hour and 5 agents l8r nightmare still not over
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE http://t.co/G9b6e0a2sZ
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue thanks for bringing my son home to me.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue HE is a lap infant (4 mons old)
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways will you please start offering more routes out of @triflight to more locations instead of just charlotte and atlanta
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Looking for practical like my adapted seat cushion allowed on?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Every flight with you has an issue!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Help?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I DMed you :)
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @AmericanAir thanks so much!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Will I be able to leave Miami Airport during my 12 hour stopover there?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I chatted with a nice fella about it and he gave me the lowdown.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @AmericanAir great job and great service in and out of SDF this weekend during the winter storm.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @usairways &amp; @AmericanAir planes in #grandcayman http://t.co/GX7QbtckBr
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united the worst customer service in Denver.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE They could learn so much from you!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united aaaand 7 hours Late Flightr won't be catching a flight til 6AM...stuck in at airport in a snowstorm with no hotel-how's that for patience?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I really appreciated her help this morning!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE No more faith in United.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Unlike the @nyjets. ;-) #GoPatriots!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE U need a better system!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE You pay $500 for a ticket and get a fraction of that as PQD credit?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE .. refuse to let us board with baby early... time we board wont let us take baby carryon bag
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE And can I bring a companion?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir loved it!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Status should matter.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE We are through.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united still waiting for a response on whether or not you allow use of a rear facing car seat on an ERJ145.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir @SwagglikeBean take me here
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Not impressed so far :-/.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir I would love a great deal from bwi to las Memorial Day weekend aka my bday weekend 😬
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE My tweet was out of frustration
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united ...and when that doesn't work...
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Seat 27D. Did anyone find it?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@JetBlue thx
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #canthurtasking
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @AmericanAir help http://t.co/hYrAo7A4Uu
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE It is ridiculous!!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE No excuse for attitude &amp; ripping up our tickets!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #nothappy
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united is there a referral program for the Milageplus explorer card?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @AmericanAir I need to be back in Cleveland as early as possible tomorrow
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #LOL
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united 777 from SFO to HNL with ZERO entertainment systems???!!!#youareonyourown
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE ^EY” 👏👏
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE 4 hr delays need to be explained better.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE more info here: http://t.co/FvlxIRh1F1 #LookforwardtoflywithAA
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@JetBlue CEO weighs profits
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Rather than fix it they put a broken sign on it and separated me from my kids.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE STOP MESSING WITH MY LIFE.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I just fill in the form #idnumber8569822 #hopetogetanswersoon
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Thanks...seat made for a 6 year old and a broken TV. 20 flights/year...my last on your airline.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE http://t.co/H3k3oWOhD1
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Total failure by you and your partners in ensuring the best customer experience.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways thanks for getting me rescheduled on a direct flight to NOLA tonight in 10 minutes--and hopefully an hour earlier getting there!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@SouthwestAir understand the weather
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Makes 10 straight delays
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE A+ work.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Smoothest landing ever.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united my flight landed 50 min
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways what's your pet policy?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Thanks.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united why would a person take hours and hours of wait time just to tell a lie
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united ouch not fair
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue I would go anywhere JetBlue goes.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Thank you!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united i got it at the gate
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE do I need to change that?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Not what's been shared by the pilot with passengers!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united same day flights
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Much appreciated!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE FOLLOW ME BACK
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@VirginAmerica just promoting the product is all
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #southwestrocks
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir a nice trip back home after a looong vaca 😊🌴 http://t.co/9TRvfnCedL
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united you guys have such big hearts.. keep up the good work
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@JetBlue I want to enter the family pooling contest
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Can you help?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united @rayja9 flying to las vegas out of Chicago flight is Late Flight and no announcement has been made
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united It's the fact that an international should not be with out her bag and no sense of what's going on other than ""maintenance""."
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Doesn't change the fact that I'm very inconveniently missing my luggage tonight.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Thank you!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE pls let me know when u start!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united thanks gate agent extraordinaire Seau Fong for helping me get re-booked out of Boise and (hopefully) home to NYC sometime tonight!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united has terrible customer service &amp; doesn't feel the need to notify its customers when their flights are delayed
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE AA1679 Another successful journey
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united DM sent.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Thanks #southwest for making travel easy!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united (2/2) I have their name (boarding pass was in there
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Thanks
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #oscars2016
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Apparently they are asking 20 people to off board the plane--how can such a big miscalculation be made?!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Going to Orlando on flight 723
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE If you do something to make up for it I'll tweet that too.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE :)
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united no announcement re extra baggage
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united passengers should have been rerouted to match the intended arrival time (even if you have to incur cost to put us in other airlines)
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Next Stop Portland!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united &amp; finally he was told he couldnt use the front of plane restrm (he was row7) though myself/others in rows behind him used w/no issue
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I'll take them.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I'm a mileage plus card member 😔
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Very disappointed in your customer service.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Iceland should be fun with no clothes....
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Or maybe I'm extra bloated.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Arrive at gate stopped cause now infant is sitting in 4 yr old lap
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir you're the best
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE We status match AA. ^KP”
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Does this mean we will acquire miles based on price or distance flown?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Just upset that my travel office had to fix this
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@VirginAmerica first time flying Virgin
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE http://t.co/xmRvR4lGEg http://t.co/wJoc9f14SU”@tori_leggieri
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Gotta LUV them :)
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Stuck in Houston because you can't seem to get a plane to the destination on time in perfect flying conditions.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Glad to have been of service!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Arriving at the airport 2 hours before departure time and still missing your flight bc you actually don't have an electronic ticket
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united It wasn't full
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united @nathankillam or your staff could try not throwing the luggage around.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #ridiculous #UnitedAirlines
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Thx for listening to me vent.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Kudos to flight crew and airline in general.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @AmericanAir and is there a delay on our connection to pns?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Renting a car.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Incredibly helpful.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #HORRIBLE
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I've tried both desktop and mobile http://t.co/AvyqdMpi1Y
# INPUT TO VADER []
# ...
#
# INPUT SENTENCE Today's been tough
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE http://t.co/WEZUMDimYF
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir LACMA on Fairfax.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE :)
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Staff is nasty
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #hacks #jokers #neveragain.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Your social listening capabilities are awful if this is the reply for the context in which you were mentioned @stevelord212
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE - @CAPA_Aviation http://t.co/vGqOihtRkH
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue's CEO battles to appease passengers and Wall Street - Waterbury Republican American http://t.co/Xf9MPnAaJE
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #gottogetbetter
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united Once again I am victim to the scam that is your SHIT Customer Service
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #fedup #disastrous
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Sending DM with ref number.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways OK she is worried that something is wrong with the flight - #1870 - and should she consider flying earlier
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Despite the mind boggling wait time
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Cannot figure out where to go to get it.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #awesome
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @AmericanAir is flight 2413 to LA delayed?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@JetBlue I'd go to Portsmouth
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Seriously?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE B/C of the inexpensive airfares that Southwest has I can now travel around.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #trueblue  JetBlue gets social.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@AmericanAir Thanks
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir @Imaginedragons #DestinationDragons Scavenger Hunt rules: http://t.co/vHgkiTzSaw
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue I would like to receive offers.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Worst airline ever.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir Is it possible to add companion to only the 2nd leg of a trip?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways so what is the  difference between Cancelled Flighting and reFlight Booking Problems - will that help me avoid a change fee?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue my family and I are excited to see you too😊😊
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #UA6136 http://t.co/4JdvK8tCqx"
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE He also wants the money..
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #flyingitforward http://t.co/lTf2quD3Xc
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #epicfailunited
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE What to do?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Thanks!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united - please help regarding PNR A3ZZ0F. Why am I now waitlisted for a flight?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@JetBlue be flying soon to NYC on your airline
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE We are very upset.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@VirginAmerica awaiting my return phone call
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Traveled 8000 miles roundtrip but two Cancelled Flightlations of short hops cost me two days
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #americanairlines #americanair
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united I am buying 2 yo own seat on 3 legs of intl trip
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE can it be changed?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE 1079871763
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #scheduling
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #badservice
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@SouthwestAir   Happily
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE hanging up on customers intentionally after one hour on hold.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #fail #lazy #alwaysLate Flight #worstairlineever
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE And indeed
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I need to get home for my pops funeral
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue your customer service agent Bonnie is amazing on the phone she deserves a promotion!!!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE We'll see about that tomorrow morning when I have to fight for a seat.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways following you now
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE When will u guys learn?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@AmericanAir Next Friday
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #DestinationDragons
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE We are finally at the gate.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE As a business owner
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Yeah cold
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE A+ service!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @VirginAmerica i would like help with some flights please.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir loving the boarding to go to Chicago #KeepItMovin'
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Thank you!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #oscars2016
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Is there a UK number I could try?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united has not responded to my various requests for contact numbers
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@AmericanAir I love very much your planes
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Thank you!!!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Haven't heard back and I'm flying this week #disappointed
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Never been on ur planes but now I will!!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@JetBlue yes
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE It would mean so much to me #DestinationDragons
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE #travel #friendlyteam
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united sent DM's
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united oh
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Apart from being on hold for over 2 hours and having talked to 5 people and the problem still not resolved!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE http://t.co/dxn58rxDkS”@jameskraw see.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways thanks.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir  how do you get one?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Now we are waiting for a flight attendant as one just walked off &amp; left http://t.co/IpaamZT7Z2
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @VirginAmerica what is your policy on flying after surgery?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united it's 9:56
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@United Right now at Tropic Air in San Pedro
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united Can you tell me Jet Airways award availability?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE NYC was awesomeee!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE With a group and over 20 luggages are lost
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I'm running iOS 8.1.3
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Extremely unlikely I will make it!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united it's disgusting and unconscionable the treatment I've received tonight.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE 25 min. @ABC11_WTVD
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Fingers Crossed!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE http://t.co/3zpJr7kWbk
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue will we be able to watch the Oscars on our flight tomorrow?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Just double checking bc the site looked different.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @united I want a hotel room and a whiskey.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@JetBlue Well
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue but Virgin has wifi 👀
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE You should be very proud :) http://t.co/oKtUkjY92O (via @ParachuteGuy)
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I was stuck for 35 hours because of you guys
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @JetBlue Sent.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways can you help me reroute my trip?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I'd like to call them myself.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir Arkansas Gov. plans to sign Governor SB-202 that legalizes discrimination of LGBT.Can you lend your voice to a state boycott?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Can this get any worse.
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE I’ll look forward to hopefully one of those 103 on my flight home tonight :)
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE "@united hi JP
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE Thanks a lot!!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @USAirways is a DM possible if you aren't following me?
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE To top things off
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir safety back in Dallas!
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# INPUT SENTENCE @SouthwestAir I'm flying out of CUN tomorrow To DEN - can I change my flight due to the travel advisory??
# INPUT TO VADER []
# VADER OUTPUT {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}

# %% [markdown]
# ## Part II: scikit-learn assignments
# ### [4 points] Question 5
# Train the scikit-learn classifier (Naive Bayes) using the airline tweets.
#
# + Train the model on the airline tweets with 80% training and 20% test set and default settings (TF-IDF representation, min_df=2)
# + Train with different settings:
#     + with respect to vectorizing: TF-IDF ('airline_tfidf') vs. Bag of words representation ('airline_count')
#     + with respect to the frequency threshold (min_df). Carry out experiments with increasing values for document frequency (min_df = 2; min_df = 5; min_df =10)
# * [1 point] a. Generate a classification_report for all experiments
# * [3 points] b. Look at the results of the experiments with the different settings and try to explain why they differ:
#     + which category performs best, is this the case for any setting?
#     + does the frequency threshold affect the scores? Why or why not according to you?

# %%
# Your code here

# %% [markdown]
# ### [4 points] Question 6: Inspecting the best scoring features
#
# + Train the scikit-learn classifier (Naive Bayes) model with the following settings (airline tweets 80% training and 20% test;  Bag of words representation ('airline_count'), min_df=2)
# * [1 point] a. Generate the list of best scoring features per class (see function **important_features_per_class** below) [1 point]
# * [3 points] b. Look at the lists and consider the following issues:
#     + [1 point] Which features did you expect for each separate class and why?
#     + [1 point] Which features did you not expect and why ?
#     + [1 point] The list contains all kinds of words such as names of airlines, punctuation, numbers and content words (e.g., 'delay' and 'bad'). Which words would you remove or keep when trying to improve the model and why?

# %%
def important_features_per_class(vectorizer,classifier,n=80):
    class_labels = classifier.classes_
    feature_names =vectorizer.get_feature_names()
    topn_class1 = sorted(zip(classifier.feature_count_[0], feature_names),reverse=True)[:n]
    topn_class2 = sorted(zip(classifier.feature_count_[1], feature_names),reverse=True)[:n]
    topn_class3 = sorted(zip(classifier.feature_count_[2], feature_names),reverse=True)[:n]
    print("Important words in negative documents")
    for coef, feat in topn_class1:
        print(class_labels[0], coef, feat)
    print("-----------------------------------------")
    print("Important words in neutral documents")
    for coef, feat in topn_class2:
        print(class_labels[1], coef, feat) 
    print("-----------------------------------------")
    print("Important words in positive documents")
    for coef, feat in topn_class3:
        print(class_labels[2], coef, feat) 

# example of how to call from notebook:
#important_features_per_class(airline_vec, clf)

# %% [markdown]
# ### [Optional! (will not  be graded)] Question 7
# Train the model on airline tweets and test it on your own set of tweets
# + Train the model with the following settings (airline tweets 80% training and 20% test;  Bag of words representation ('airline_count'), min_df=2)
# + Apply the model on your own set of tweets and generate the classification report
# * [1 point] a. Carry out a quantitative analysis.
# * [1 point] b. Carry out an error analysis on 10 correctly and 10 incorrectly classified tweets and discuss them
# * [2 points] c. Compare the results (cf. classification report) with the results obtained by VADER on the same tweets and discuss the differences.

# %% [markdown]
# ### [Optional! (will not be graded)] Question 8: trying to improve the model
# * [2 points] a. Think of some ways to improve the scikit-learn Naive Bayes model by playing with the settings or applying linguistic preprocessing (e.g., by filtering on part-of-speech, or removing punctuation). Do not change the classifier but continue using the Naive Bayes classifier. Explain what the effects might be of these other settings
# + [1 point] b. Apply the model with at least one new setting (train on the airline tweets using 80% training, 20% test) and generate the scores
# * [1 point] c. Discuss whether the model achieved what you expected.

# %% [markdown]
# ## End of this notebook
